# %%
import matplotlib.pyplot as plt
import mlflow
import pandas as pd
import seaborn as sns
import os
import numpy as np
from hp import *
from utils import *
from keras import initializers
os.makedirs("images", exist_ok=True)


# %load_ext autoreload
# %autoreload 2
# Out:
# 2023-05-23 14:37:30.480168: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-23 14:37:30.512261: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-23 14:37:30.513081: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-23 14:37:31.043123: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-23 14:37:31.699568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-23 14:37:31.723865: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# ## Plot style

# %%
# https://jwalton.info/Embed-Publication-Matplotlib-Latex/
tex_fonts = {
    # Use LaTeX to write all text
    "text.latex.preamble": r"\usepackage[T1]{fontenc}\usepackage{amsfonts}\usepackage{amsmath}\usepackage{amssymb}",  #  for the align enivironment
    "text.usetex": True,  # use inline math for ticks
    "font.family": "serif",
    "pgf.rcfonts": False,  # don't setup fonts from rc parameters
    "savefig.transparent": True,
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 9,
    "font.size": 9,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 7,
    "xtick.labelsize": 7,
    "ytick.labelsize": 7,
}

plt.rcParams.update(tex_fonts)
textwidth = 430
columnwidth = 252

# %%
# https://jwalton.info/Embed-Publication-Matplotlib-Latex/
def set_size(width, fraction=1, subplots=(1, 1)):
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float or string
            Document width in points, or string of predined document type
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy
    subplots: array-like, optional
            The number of rows and columns of subplots.
    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    width_pt = width

    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5**0.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %% [markdown]
# # Fit function and parameters

# %%
def fit_func_prepare(params, data_path):
    data = load_data(data_path)
    train_data = (data["x_train"], data["y_train"])
    val_data = (data["x_test"], data["y_test"])

    model_type = params["model_type"]
    model_kwargs = get_model_kwargs(model_type)
    params = {**params, **model_kwargs}

    x_args = params.pop("net_x_arch_trunk_args")
    params["net_x_arch_trunk"] = relu_network(
        [x_args["x_units"]] * x_args["x_layers"], dropout=x_args["dropout"]
    )
    y_args = params.pop("net_y_size_trunk_args")
    params["net_y_size_trunk"] = nonneg_tanh_network(y_args["y_base_units"],
        dropout=y_args["dropout"], **y_args["kwargs"]
    )

    seed = params.pop("seed")
    set_seeds(seed)
    return train_data,val_data, params

def fit_func(params, data_path, fast):
    train_data, val_data, params = fit_func_prepare(params, data_path)
    hist, neat_model = fit(
        epochs=20 if fast else 10_000,
        train_data=train_data,
        val_data=val_data,
        **params,
    )
    return neat_model, hist

data_path = "energy"
hp_param = {
            "seed": 1,
            "net_x_arch_trunk_args": {
                "x_units": 20,
                "x_layers": 1,
                "dropout": 0,
            },
            "net_y_size_trunk_args": {
                "y_base_units": [100,100,20],
                "dropout": 0.0,
                "kwargs": dict(kernel_initializer=initializers.RandomUniform(minval=0., maxval=1.))
                # "kwargs": dict(kernel_initializer=constraint_xavier_init)
            },
            "optimizer": Adam(learning_rate=1e-3),
            "base_distribution": tfd.Normal(loc=0, scale=1),
            "model_type": ModelType.LS,
        }

# %% [markdown]
# # Train "large" model with RandomUniform(0,1) initialisation

# %%
neat_model, hist = fit_func(hp_param, data_path, fast=True)
# Out:
# Epoch 1/20
# /home/marcel/.conda/envs/neat/lib/python3.10/site-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# 22/22 [==============================] - 1s 11ms/step - logLik: 665.0287 - val_logLik: 270.4950
# Epoch 2/20
# 22/22 [==============================] - 0s 4ms/step - logLik: 622.1157 - val_logLik: 258.6957
# Epoch 3/20
# 22/22 [==============================] - 0s 4ms/step - logLik: 606.9454 - val_logLik: 254.6276
# Epoch 4/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 601.7172 - val_logLik: 253.0622
# Epoch 5/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 599.7284 - val_logLik: 252.4899
# Epoch 6/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 598.8748 - val_logLik: 252.2689
# Epoch 7/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 598.5305 - val_logLik: 252.1441
# Epoch 8/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 598.2930 - val_logLik: 252.0675
# Epoch 9/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 598.1006 - val_logLik: 252.0054
# Epoch 10/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.9795 - val_logLik: 251.9468
# Epoch 11/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.8589 - val_logLik: 251.9101
# Epoch 12/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.7734 - val_logLik: 251.8717
# Epoch 13/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.7005 - val_logLik: 251.8387
# Epoch 14/20
# 22/22 [==============================] - 0s 6ms/step - logLik: 597.6274 - val_logLik: 251.8052
# Epoch 15/20
# 22/22 [==============================] - 0s 6ms/step - logLik: 597.5750 - val_logLik: 251.7803
# Epoch 16/20
# 22/22 [==============================] - 0s 6ms/step - logLik: 597.5200 - val_logLik: 251.7616
# Epoch 17/20
# 22/22 [==============================] - 0s 6ms/step - logLik: 597.4827 - val_logLik: 251.7344
# Epoch 18/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.4488 - val_logLik: 251.7238
# Epoch 19/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.4090 - val_logLik: 251.7009
# Epoch 20/20
# 22/22 [==============================] - 0s 5ms/step - logLik: 597.3786 - val_logLik: 251.6780

# %%
plt.plot(hist.history['logLik'], label='train')
plt.plot(hist.history['val_logLik'], label='valid')
plt.legend()

# %% [markdown]
# ### plot transformation function

# %%
yy = np.linspace(-5,5,100)
xx = np.zeros((yy.shape[0], 8))
z = neat_model.predict((xx,yy))
plt.figure(figsize=set_size(textwidth))
plt.title(r"Transformation function with initialisation $U(0,1)$")
plt.xlabel(r"$y$")
plt.ylabel(r"$g(y|x=0)$")
plt.scatter(yy, z)
plt.savefig("images/initialisation_u(01).pdf")
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %% [markdown]
# # Train "large" model with adapted Xavier initialisation

# %%
data_path = "energy"
def constraint_xavier_p_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    # limit = np.sqrt(6. / (fan_in+fan_out))
    limit = np.sqrt(9. / (np.max([fan_in, fan_out])**2))
    return tf.random.uniform(shape, minval=0, maxval=limit, dtype=dtype)
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=constraint_xavier_p_init)
neat_model, hist = fit_func(hp_param, data_path, fast=False)
# Out:
# Epoch 1/10000
# 22/22 [==============================] - 1s 11ms/step - logLik: 60.4678 - val_logLik: 14.0688
# Epoch 2/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: 28.3669 - val_logLik: 8.4906
# Epoch 3/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: 18.3284 - val_logLik: 5.4930
# Epoch 4/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: 11.9264 - val_logLik: 3.3627
# Epoch 5/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: 7.5178 - val_logLik: 1.7535
# Epoch 6/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: 5.5894 - val_logLik: 1.0809
# Epoch 7/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: 3.5762 - val_logLik: 0.8105
# Epoch 8/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: 1.9227 - val_logLik: -0.2059
# Epoch 9/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -0.1449 - val_logLik: -0.7028
# Epoch 10/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -1.2727 - val_logLik: -1.5097
# Epoch 11/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -2.0402 - val_logLik: -1.3513
# Epoch 12/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -2.6503 - val_logLik: -0.4263
# Epoch 13/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -3.2826 - val_logLik: -1.7808
# Epoch 14/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -2.7379 - val_logLik: -0.9129
# Epoch 15/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -2.9015 - val_logLik: -1.1420
# Epoch 16/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -5.3162 - val_logLik: -1.5497
# Epoch 17/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -5.0659 - val_logLik: -1.4017
# Epoch 18/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -6.1535 - val_logLik: -1.5889
# Epoch 19/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -6.2647 - val_logLik: -1.4440
# Epoch 20/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -5.9983 - val_logLik: -0.8142
# Epoch 21/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -7.2931 - val_logLik: -0.6701
# Epoch 22/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -7.2422 - val_logLik: -1.7704
# Epoch 23/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -7.4826 - val_logLik: -2.0603
# Epoch 24/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -8.3382 - val_logLik: -2.0284
# Epoch 25/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -8.2152 - val_logLik: -0.7791
# Epoch 26/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -7.3292 - val_logLik: -2.0304
# Epoch 27/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.0204 - val_logLik: -2.0241
# Epoch 28/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -8.4895 - val_logLik: -1.9324
# Epoch 29/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -8.8350 - val_logLik: -1.8239
# Epoch 30/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -9.4846 - val_logLik: -1.8508
# Epoch 31/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.5564 - val_logLik: -2.1001
# Epoch 32/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -8.5939 - val_logLik: -1.4187
# Epoch 33/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.6922 - val_logLik: -1.6871
# Epoch 34/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -9.9348 - val_logLik: -1.6305
# Epoch 35/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -9.7544 - val_logLik: -2.1357
# Epoch 36/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -10.0873 - val_logLik: -1.4788
# Epoch 37/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.8459 - val_logLik: -0.2360
# Epoch 38/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -10.2086 - val_logLik: -0.7848
# Epoch 39/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.2607 - val_logLik: -1.6021
# Epoch 40/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -10.2682 - val_logLik: -1.6007
# Epoch 41/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -10.3012 - val_logLik: -1.5207
# Epoch 42/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -10.8477 - val_logLik: -1.8104
# Epoch 43/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -10.1346 - val_logLik: -1.5051
# Epoch 44/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.0028 - val_logLik: -1.5450
# Epoch 45/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.0674 - val_logLik: -1.6997
# Epoch 46/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -10.6020 - val_logLik: 0.5308
# Epoch 47/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -10.0459 - val_logLik: -1.8969
# Epoch 48/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.3234 - val_logLik: -1.0705
# Epoch 49/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.1635 - val_logLik: -1.6713
# Epoch 50/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.6939 - val_logLik: -0.7205
# Epoch 51/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.4501 - val_logLik: -1.6544
# Epoch 52/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.0089 - val_logLik: -1.8897
# Epoch 53/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.1105 - val_logLik: -0.2101
# Epoch 54/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.9255 - val_logLik: -1.1510
# Epoch 55/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.0799 - val_logLik: -1.4766
# Epoch 56/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.2112 - val_logLik: 0.3137
# Epoch 57/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.5502 - val_logLik: -1.8649
# Epoch 58/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.5446 - val_logLik: -1.0813
# Epoch 59/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.9046 - val_logLik: -1.9195
# Epoch 60/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.8583 - val_logLik: -1.5137
# Epoch 61/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.0944 - val_logLik: -1.8572
# Epoch 62/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.6468 - val_logLik: -1.9297
# Epoch 63/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.0046 - val_logLik: 0.9390
# Epoch 64/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -10.4006 - val_logLik: -1.4915
# Epoch 65/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -10.8716 - val_logLik: -0.6070
# Epoch 66/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -9.5039 - val_logLik: -0.6531
# Epoch 67/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.1517 - val_logLik: -2.0852
# Epoch 68/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.8058 - val_logLik: -1.1530
# Epoch 69/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.1813 - val_logLik: -0.6764
# Epoch 70/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.9452 - val_logLik: -2.2154
# Epoch 71/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.9101 - val_logLik: -1.2566
# Epoch 72/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.5895 - val_logLik: -1.7944
# Epoch 73/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.6264 - val_logLik: -1.3647
# Epoch 74/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.5611 - val_logLik: -1.8980
# Epoch 75/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.0361 - val_logLik: -1.3529
# Epoch 76/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.3419 - val_logLik: -0.7573
# Epoch 77/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.8333 - val_logLik: -1.2093
# Epoch 78/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.2292 - val_logLik: -1.2855
# Epoch 79/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -11.0193 - val_logLik: -1.6638
# Epoch 80/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -11.8355 - val_logLik: -1.3269
# Epoch 81/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.1286 - val_logLik: -0.8290
# Epoch 82/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.5963 - val_logLik: -1.7613
# Epoch 83/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.1424 - val_logLik: -2.0630
# Epoch 84/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.2159 - val_logLik: -1.0733
# Epoch 85/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.3809 - val_logLik: -0.8645
# Epoch 86/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.2036 - val_logLik: -1.7604
# Epoch 87/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.7058 - val_logLik: -1.6839
# Epoch 88/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.3811 - val_logLik: -1.6097
# Epoch 89/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.5683 - val_logLik: -1.7900
# Epoch 90/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -12.8691 - val_logLik: -1.7686
# Epoch 91/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.7452 - val_logLik: -0.6993
# Epoch 92/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.2477 - val_logLik: -1.9664
# Epoch 93/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.2665 - val_logLik: -1.2704
# Epoch 94/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.0191 - val_logLik: -0.5274
# Epoch 95/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -13.2770 - val_logLik: -1.1012
# Epoch 96/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.4064 - val_logLik: -0.7135
# Epoch 97/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.6400 - val_logLik: -1.3466
# Epoch 98/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.6118 - val_logLik: -1.7054
# Epoch 99/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.1053 - val_logLik: -1.6217
# Epoch 100/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.9705 - val_logLik: -0.3266
# Epoch 101/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.8342 - val_logLik: -1.9972
# Epoch 102/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.1652 - val_logLik: -1.1474
# Epoch 103/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.3002 - val_logLik: -1.7142
# Epoch 104/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.5171 - val_logLik: -1.1934
# Epoch 105/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.2175 - val_logLik: -1.9112
# Epoch 106/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.2302 - val_logLik: -1.8254
# Epoch 107/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.2928 - val_logLik: -1.8664
# Epoch 108/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.8409 - val_logLik: -1.4620
# Epoch 109/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -13.8994 - val_logLik: -2.3931
# Epoch 110/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.3515 - val_logLik: -1.6686
# Epoch 111/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.5920 - val_logLik: -1.0915
# Epoch 112/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.8677 - val_logLik: -2.2982
# Epoch 113/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.7897 - val_logLik: -1.7836
# Epoch 114/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.7616 - val_logLik: -2.1011
# Epoch 115/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.8591 - val_logLik: -1.7028
# Epoch 116/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.5949 - val_logLik: 0.8402
# Epoch 117/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.1589 - val_logLik: -1.8289
# Epoch 118/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.0009 - val_logLik: -1.6171
# Epoch 119/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.2652 - val_logLik: -1.6323
# Epoch 120/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.5192 - val_logLik: -1.5113
# Epoch 121/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.5606 - val_logLik: -1.6384
# Epoch 122/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -14.5609 - val_logLik: -1.8272
# Epoch 123/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -15.3960 - val_logLik: -2.4201
# Epoch 124/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.0308 - val_logLik: -1.6703
# Epoch 125/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.9608 - val_logLik: -1.2167
# Epoch 126/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.2996 - val_logLik: -1.6556
# Epoch 127/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.7437 - val_logLik: -1.7683
# Epoch 128/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -16.0574 - val_logLik: 0.4397
# Epoch 129/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.0574 - val_logLik: -1.8224
# Epoch 130/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.6695 - val_logLik: -1.3906
# Epoch 131/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -15.9297 - val_logLik: -2.5286
# Epoch 132/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.9538 - val_logLik: 0.1419
# Epoch 133/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -13.1320 - val_logLik: -2.2178
# Epoch 134/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -12.7741 - val_logLik: -0.2653
# Epoch 135/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.9791 - val_logLik: -0.1172
# Epoch 136/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -14.1403 - val_logLik: -2.5232
# Epoch 137/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -16.1192 - val_logLik: -2.2465
# Epoch 138/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.1309 - val_logLik: -2.1069
# Epoch 139/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.5754 - val_logLik: -1.1849
# Epoch 140/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.2460 - val_logLik: -1.2291
# Epoch 141/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.9359 - val_logLik: -2.1808
# Epoch 142/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -16.0079 - val_logLik: -2.4303
# Epoch 143/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.4286 - val_logLik: -1.8069
# Epoch 144/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -17.0298 - val_logLik: -1.4188
# Epoch 145/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.8564 - val_logLik: -2.5534
# Epoch 146/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -17.0136 - val_logLik: -2.2563
# Epoch 147/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.2606 - val_logLik: -1.6451
# Epoch 148/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.4564 - val_logLik: -2.0419
# Epoch 149/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.1232 - val_logLik: -0.8896
# Epoch 150/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.5654 - val_logLik: -1.3962
# Epoch 151/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -15.7655 - val_logLik: -1.6910
# Epoch 152/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.0204 - val_logLik: -2.2128
# Epoch 153/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.1583 - val_logLik: -1.4956
# Epoch 154/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -16.8467 - val_logLik: -2.8389
# Epoch 155/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -15.8491 - val_logLik: -0.8360
# Epoch 156/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.3862 - val_logLik: -1.4356
# Epoch 157/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.0954 - val_logLik: -1.1304
# Epoch 158/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.2562 - val_logLik: -1.0368
# Epoch 159/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.0915 - val_logLik: -2.3813
# Epoch 160/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.1396 - val_logLik: -0.7508
# Epoch 161/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.1352 - val_logLik: -3.0899
# Epoch 162/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.7746 - val_logLik: -1.7634
# Epoch 163/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.6141 - val_logLik: -2.8437
# Epoch 164/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -17.4676 - val_logLik: -1.1910
# Epoch 165/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.7926 - val_logLik: -2.2308
# Epoch 166/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.1398 - val_logLik: -2.8752
# Epoch 167/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.1749 - val_logLik: -1.4363
# Epoch 168/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.9530 - val_logLik: 0.8301
# Epoch 169/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.1589 - val_logLik: -2.5314
# Epoch 170/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.0875 - val_logLik: -1.3964
# Epoch 171/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.2142 - val_logLik: -2.9831
# Epoch 172/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.1997 - val_logLik: -1.4456
# Epoch 173/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.6424 - val_logLik: -2.4741
# Epoch 174/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.1580 - val_logLik: -2.4022
# Epoch 175/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.5477 - val_logLik: -1.3355
# Epoch 176/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -16.7328 - val_logLik: -2.2828
# Epoch 177/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.6699 - val_logLik: -2.4836
# Epoch 178/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.0131 - val_logLik: -2.4879
# Epoch 179/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.5126 - val_logLik: -2.6984
# Epoch 180/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.9001 - val_logLik: -1.8623
# Epoch 181/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.3401 - val_logLik: -1.6196
# Epoch 182/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.7488 - val_logLik: -2.0764
# Epoch 183/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.8162 - val_logLik: -2.8786
# Epoch 184/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.6914 - val_logLik: -1.1983
# Epoch 185/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.2733 - val_logLik: -2.7312
# Epoch 186/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -17.5821 - val_logLik: -2.0841
# Epoch 187/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.9072 - val_logLik: -3.3008
# Epoch 188/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.6198 - val_logLik: -0.5558
# Epoch 189/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.6245 - val_logLik: -3.2938
# Epoch 190/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.3976 - val_logLik: -2.9103
# Epoch 191/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -19.2090 - val_logLik: -2.6855
# Epoch 192/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.7158 - val_logLik: -2.0939
# Epoch 193/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.5875 - val_logLik: -3.0208
# Epoch 194/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.7164 - val_logLik: -3.0515
# Epoch 195/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.0860 - val_logLik: -3.3024
# Epoch 196/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.1148 - val_logLik: -2.6858
# Epoch 197/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.5152 - val_logLik: -1.9269
# Epoch 198/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -19.4693 - val_logLik: -2.9968
# Epoch 199/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8454 - val_logLik: -2.2606
# Epoch 200/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.0699 - val_logLik: -1.7359
# Epoch 201/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -18.5248 - val_logLik: -2.9734
# Epoch 202/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.4618 - val_logLik: -3.0942
# Epoch 203/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.0508 - val_logLik: -2.4423
# Epoch 204/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8950 - val_logLik: -3.5275
# Epoch 205/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8295 - val_logLik: -2.8156
# Epoch 206/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.1473 - val_logLik: -3.7112
# Epoch 207/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -20.3225 - val_logLik: -3.4111
# Epoch 208/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.3771 - val_logLik: -3.5555
# Epoch 209/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -19.7588 - val_logLik: -3.7484
# Epoch 210/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8997 - val_logLik: -2.8707
# Epoch 211/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -20.4971 - val_logLik: -2.4597
# Epoch 212/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.0592 - val_logLik: -3.6821
# Epoch 213/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -19.9369 - val_logLik: -2.9878
# Epoch 214/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.0368 - val_logLik: -3.7084
# Epoch 215/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.4288 - val_logLik: -3.2808
# Epoch 216/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -20.2614 - val_logLik: -3.6135
# Epoch 217/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.2513 - val_logLik: -3.3613
# Epoch 218/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.4189 - val_logLik: -4.0728
# Epoch 219/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -20.7332 - val_logLik: -3.9205
# Epoch 220/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.0321 - val_logLik: -3.0537
# Epoch 221/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8005 - val_logLik: -3.1464
# Epoch 222/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -20.7607 - val_logLik: -3.0506
# Epoch 223/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.3444 - val_logLik: -4.2790
# Epoch 224/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.7267 - val_logLik: -2.3777
# Epoch 225/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.8456 - val_logLik: -4.2066
# Epoch 226/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.7112 - val_logLik: -2.8640
# Epoch 227/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.1117 - val_logLik: -4.3886
# Epoch 228/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -19.7555 - val_logLik: -3.2444
# Epoch 229/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -18.7096 - val_logLik: -2.1775
# Epoch 230/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -20.0176 - val_logLik: -4.6005
# Epoch 231/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.3722 - val_logLik: -4.7900
# Epoch 232/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.7656 - val_logLik: -2.6269
# Epoch 233/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.3357 - val_logLik: -4.0483
# Epoch 234/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.4316 - val_logLik: -4.6092
# Epoch 235/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.5410 - val_logLik: -2.8155
# Epoch 236/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.9864 - val_logLik: -4.0006
# Epoch 237/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.0322 - val_logLik: -3.4446
# Epoch 238/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.3893 - val_logLik: -4.7935
# Epoch 239/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.2598 - val_logLik: -4.5196
# Epoch 240/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.8804 - val_logLik: -4.3254
# Epoch 241/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -21.7165 - val_logLik: -3.9492
# Epoch 242/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.0888 - val_logLik: -4.5177
# Epoch 243/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.9308 - val_logLik: -4.3771
# Epoch 244/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.4557 - val_logLik: -3.0049
# Epoch 245/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -21.0565 - val_logLik: -4.5060
# Epoch 246/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.7711 - val_logLik: -4.5095
# Epoch 247/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.5297 - val_logLik: -4.0967
# Epoch 248/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -21.4523 - val_logLik: -3.6367
# Epoch 249/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.8508 - val_logLik: -4.3514
# Epoch 250/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.0090 - val_logLik: -3.3009
# Epoch 251/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.0476 - val_logLik: -4.1240
# Epoch 252/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.2838 - val_logLik: -4.4138
# Epoch 253/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.8338 - val_logLik: -3.9830
# Epoch 254/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.9382 - val_logLik: -5.3523
# Epoch 255/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.1289 - val_logLik: -2.6662
# Epoch 256/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.6148 - val_logLik: -4.9974
# Epoch 257/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.9408 - val_logLik: -4.2637
# Epoch 258/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.4787 - val_logLik: -4.4853
# Epoch 259/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.2620 - val_logLik: -4.4700
# Epoch 260/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.3134 - val_logLik: -5.3602
# Epoch 261/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.5339 - val_logLik: -4.7505
# Epoch 262/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.0297 - val_logLik: -5.0233
# Epoch 263/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -20.9192 - val_logLik: -2.7371
# Epoch 264/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.1909 - val_logLik: -4.6115
# Epoch 265/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.5720 - val_logLik: -5.4351
# Epoch 266/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.6631 - val_logLik: -5.1881
# Epoch 267/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.7877 - val_logLik: -4.4730
# Epoch 268/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.2358 - val_logLik: -5.0267
# Epoch 269/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.3229 - val_logLik: -4.2352
# Epoch 270/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -21.9020 - val_logLik: -4.6091
# Epoch 271/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.5511 - val_logLik: -4.0858
# Epoch 272/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -21.8824 - val_logLik: -5.2924
# Epoch 273/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.3403 - val_logLik: -4.8442
# Epoch 274/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.1290 - val_logLik: -5.4425
# Epoch 275/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.4901 - val_logLik: -6.0278
# Epoch 276/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.2346 - val_logLik: -5.1319
# Epoch 277/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.4811 - val_logLik: -6.0865
# Epoch 278/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -20.8744 - val_logLik: -5.0251
# Epoch 279/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.8015 - val_logLik: -3.9770
# Epoch 280/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.7810 - val_logLik: -5.3271
# Epoch 281/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.1248 - val_logLik: -5.3271
# Epoch 282/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.5147 - val_logLik: -5.2789
# Epoch 283/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.7108 - val_logLik: -6.6572
# Epoch 284/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -22.7312 - val_logLik: -5.7014
# Epoch 285/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.3255 - val_logLik: -6.1002
# Epoch 286/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -23.2531 - val_logLik: -4.9212
# Epoch 287/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -23.5464 - val_logLik: -5.1896
# Epoch 288/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.7948 - val_logLik: -6.4984
# Epoch 289/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.6417 - val_logLik: -4.5627
# Epoch 290/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.7743 - val_logLik: -6.0841
# Epoch 291/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.7911 - val_logLik: -3.9821
# Epoch 292/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.7108 - val_logLik: -7.0020
# Epoch 293/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.7861 - val_logLik: -6.8204
# Epoch 294/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.4877 - val_logLik: -5.7164
# Epoch 295/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.9460 - val_logLik: -6.1749
# Epoch 296/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.0515 - val_logLik: -5.8131
# Epoch 297/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.2544 - val_logLik: -6.3410
# Epoch 298/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.1803 - val_logLik: -4.6367
# Epoch 299/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.2300 - val_logLik: -6.4664
# Epoch 300/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.6042 - val_logLik: -4.8251
# Epoch 301/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.0104 - val_logLik: -7.4181
# Epoch 302/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.5948 - val_logLik: -6.6861
# Epoch 303/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.3649 - val_logLik: -4.7436
# Epoch 304/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.9933 - val_logLik: -7.0328
# Epoch 305/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -24.1434 - val_logLik: -3.2481
# Epoch 306/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.0003 - val_logLik: -7.0719
# Epoch 307/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.5330 - val_logLik: -6.1651
# Epoch 308/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.5926 - val_logLik: -6.0015
# Epoch 309/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.9901 - val_logLik: -7.2990
# Epoch 310/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.3788 - val_logLik: -4.9014
# Epoch 311/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.9381 - val_logLik: -6.7236
# Epoch 312/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.4198 - val_logLik: -7.3194
# Epoch 313/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.6450 - val_logLik: -5.5524
# Epoch 314/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.0118 - val_logLik: -6.7657
# Epoch 315/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.5983 - val_logLik: -7.0163
# Epoch 316/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.1710 - val_logLik: -6.4353
# Epoch 317/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.6302 - val_logLik: -7.7267
# Epoch 318/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -23.1065 - val_logLik: -6.3553
# Epoch 319/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.3092 - val_logLik: -5.6411
# Epoch 320/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.0577 - val_logLik: -7.1718
# Epoch 321/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.8335 - val_logLik: -6.6442
# Epoch 322/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.4680 - val_logLik: -6.3164
# Epoch 323/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.2551 - val_logLik: -7.0446
# Epoch 324/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.7890 - val_logLik: -7.9325
# Epoch 325/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -24.5781 - val_logLik: -5.8294
# Epoch 326/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.4985 - val_logLik: -7.3615
# Epoch 327/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.9906 - val_logLik: -5.8228
# Epoch 328/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.2037 - val_logLik: -6.0514
# Epoch 329/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.1812 - val_logLik: -4.8630
# Epoch 330/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.7334 - val_logLik: -7.6769
# Epoch 331/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.0651 - val_logLik: -7.3185
# Epoch 332/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.8788 - val_logLik: -5.8286
# Epoch 333/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.2847 - val_logLik: -5.5191
# Epoch 334/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -23.5490 - val_logLik: -7.8452
# Epoch 335/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -22.0772 - val_logLik: -7.5933
# Epoch 336/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -24.8236 - val_logLik: -6.1249
# Epoch 337/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.9102 - val_logLik: -7.9453
# Epoch 338/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.8552 - val_logLik: -5.9520
# Epoch 339/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.7143 - val_logLik: -7.3763
# Epoch 340/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.6599 - val_logLik: -6.3602
# Epoch 341/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.9112 - val_logLik: -7.7504
# Epoch 342/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.8022 - val_logLik: -4.9429
# Epoch 343/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.3625 - val_logLik: -8.1614
# Epoch 344/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.2767 - val_logLik: -4.7389
# Epoch 345/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.9208 - val_logLik: -8.3865
# Epoch 346/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.2299 - val_logLik: -7.8004
# Epoch 347/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -24.4980 - val_logLik: -7.1010
# Epoch 348/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.7018 - val_logLik: -7.3622
# Epoch 349/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.0559 - val_logLik: -8.1388
# Epoch 350/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.0722 - val_logLik: -6.6691
# Epoch 351/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.3732 - val_logLik: -6.3275
# Epoch 352/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.6471 - val_logLik: -7.9170
# Epoch 353/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.7789 - val_logLik: -8.4621
# Epoch 354/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.5697 - val_logLik: -6.6441
# Epoch 355/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.6619 - val_logLik: -8.7454
# Epoch 356/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.6904 - val_logLik: -8.4446
# Epoch 357/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.8466 - val_logLik: -6.6021
# Epoch 358/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.0345 - val_logLik: -8.1375
# Epoch 359/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.0232 - val_logLik: -6.0347
# Epoch 360/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.2054 - val_logLik: -8.3374
# Epoch 361/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.7400 - val_logLik: -5.6109
# Epoch 362/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.0732 - val_logLik: -7.7140
# Epoch 363/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.6218 - val_logLik: -7.2310
# Epoch 364/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.6220 - val_logLik: -7.1033
# Epoch 365/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.8090 - val_logLik: -8.1963
# Epoch 366/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.6477 - val_logLik: -8.0093
# Epoch 367/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.2651 - val_logLik: -7.5140
# Epoch 368/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.4154 - val_logLik: -5.7003
# Epoch 369/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.5832 - val_logLik: -8.4813
# Epoch 370/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.2054 - val_logLik: -8.4935
# Epoch 371/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.9012 - val_logLik: -7.4604
# Epoch 372/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -25.1971 - val_logLik: -8.9983
# Epoch 373/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.4547 - val_logLik: -9.0396
# Epoch 374/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.2033 - val_logLik: -8.5351
# Epoch 375/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.9379 - val_logLik: -7.1624
# Epoch 376/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.5894 - val_logLik: -6.9676
# Epoch 377/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.0917 - val_logLik: -9.5018
# Epoch 378/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.9825 - val_logLik: -4.8888
# Epoch 379/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -25.2156 - val_logLik: -6.0965
# Epoch 380/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.2546 - val_logLik: -9.8261
# Epoch 381/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.6734 - val_logLik: -8.0272
# Epoch 382/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.3915 - val_logLik: -8.7896
# Epoch 383/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.7691 - val_logLik: -7.8476
# Epoch 384/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.1358 - val_logLik: -9.8166
# Epoch 385/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.8033 - val_logLik: -7.7317
# Epoch 386/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.1725 - val_logLik: -5.5475
# Epoch 387/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -26.2278 - val_logLik: -9.7759
# Epoch 388/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.9968 - val_logLik: -8.3041
# Epoch 389/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.6696 - val_logLik: -7.4594
# Epoch 390/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.2089 - val_logLik: -7.5559
# Epoch 391/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.0263 - val_logLik: -9.4349
# Epoch 392/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.5859 - val_logLik: -9.7366
# Epoch 393/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.4596 - val_logLik: -8.2512
# Epoch 394/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.3887 - val_logLik: -7.7748
# Epoch 395/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.8141 - val_logLik: -8.3560
# Epoch 396/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -27.5878 - val_logLik: -8.5206
# Epoch 397/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.1001 - val_logLik: -8.2366
# Epoch 398/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -28.4557 - val_logLik: -9.4345
# Epoch 399/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.5246 - val_logLik: -7.4514
# Epoch 400/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.0156 - val_logLik: -9.3816
# Epoch 401/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.5269 - val_logLik: -8.5982
# Epoch 402/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.8128 - val_logLik: -9.6912
# Epoch 403/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.5660 - val_logLik: -8.7963
# Epoch 404/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.7031 - val_logLik: -8.8930
# Epoch 405/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.6339 - val_logLik: -9.8943
# Epoch 406/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.3566 - val_logLik: -10.5913
# Epoch 407/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.9915 - val_logLik: -8.5142
# Epoch 408/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.6627 - val_logLik: -10.3668
# Epoch 409/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.4375 - val_logLik: -9.8549
# Epoch 410/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -30.2630 - val_logLik: -9.5002
# Epoch 411/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.5044 - val_logLik: -9.7945
# Epoch 412/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.0362 - val_logLik: -9.7829
# Epoch 413/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.7239 - val_logLik: -9.5839
# Epoch 414/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.7683 - val_logLik: -10.0954
# Epoch 415/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.7353 - val_logLik: -10.4150
# Epoch 416/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.3459 - val_logLik: -5.3385
# Epoch 417/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -28.0782 - val_logLik: -10.2254
# Epoch 418/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.5341 - val_logLik: -9.5181
# Epoch 419/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -29.6591 - val_logLik: -9.7829
# Epoch 420/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.4591 - val_logLik: -10.2609
# Epoch 421/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -26.8323 - val_logLik: -10.1583
# Epoch 422/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.4759 - val_logLik: -7.5584
# Epoch 423/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -28.9749 - val_logLik: -9.6470
# Epoch 424/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.1205 - val_logLik: -10.1389
# Epoch 425/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.7920 - val_logLik: -10.4631
# Epoch 426/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.4387 - val_logLik: -10.3761
# Epoch 427/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.5504 - val_logLik: -8.5480
# Epoch 428/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -29.9908 - val_logLik: -10.2474
# Epoch 429/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -27.5143 - val_logLik: -9.1168
# Epoch 430/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -29.1312 - val_logLik: -8.5412
# Epoch 431/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -30.4080 - val_logLik: -9.2100
# Epoch 432/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.5428 - val_logLik: -10.4810
# Epoch 433/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.7254 - val_logLik: -10.1765
# Epoch 434/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.1841 - val_logLik: -10.3752
# Epoch 435/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.0234 - val_logLik: -11.0031
# Epoch 436/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -30.4236 - val_logLik: -10.5827
# Epoch 437/10000
# 22/22 [==============================] - 0s 7ms/step - logLik: -31.4996 - val_logLik: -11.2413
# Epoch 438/10000
# ...
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6190 - val_logLik: -19.0895
# Epoch 1870/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.3767 - val_logLik: -22.2739
# Epoch 1871/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.0739 - val_logLik: -22.4203
# Epoch 1872/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.5677 - val_logLik: -21.1997
# Epoch 1873/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.2062 - val_logLik: -21.5756
# Epoch 1874/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.8299 - val_logLik: -21.6630
# Epoch 1875/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4913 - val_logLik: -21.9799
# Epoch 1876/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.8986 - val_logLik: -21.7001
# Epoch 1877/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.2478 - val_logLik: -21.4210
# Epoch 1878/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.3955 - val_logLik: -20.9318
# Epoch 1879/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.0832 - val_logLik: -20.5156
# Epoch 1880/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.1537 - val_logLik: -21.5744
# Epoch 1881/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -45.5194 - val_logLik: -20.3022
# Epoch 1882/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.7477 - val_logLik: -21.8661
# Epoch 1883/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -45.8667 - val_logLik: -22.0743
# Epoch 1884/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.9656 - val_logLik: -20.8936
# Epoch 1885/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.6425 - val_logLik: -22.1633
# Epoch 1886/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.2342 - val_logLik: -20.9815
# Epoch 1887/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.7162 - val_logLik: -19.6496
# Epoch 1888/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.1172 - val_logLik: -20.3365
# Epoch 1889/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1678 - val_logLik: -20.2324
# Epoch 1890/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.4522 - val_logLik: -18.4134
# Epoch 1891/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.2294 - val_logLik: -20.2359
# Epoch 1892/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.0577 - val_logLik: -22.0740
# Epoch 1893/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.8107 - val_logLik: -21.1827
# Epoch 1894/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.4547 - val_logLik: -21.2088
# Epoch 1895/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4163 - val_logLik: -21.4975
# Epoch 1896/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1674 - val_logLik: -21.4419
# Epoch 1897/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.6281 - val_logLik: -18.5771
# Epoch 1898/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6788 - val_logLik: -19.7086
# Epoch 1899/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.0935 - val_logLik: -19.9517
# Epoch 1900/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.3923 - val_logLik: -20.5416
# Epoch 1901/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.4634 - val_logLik: -21.1874
# Epoch 1902/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.2140 - val_logLik: -21.8119
# Epoch 1903/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1773 - val_logLik: -21.9412
# Epoch 1904/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.7645 - val_logLik: -20.9318
# Epoch 1905/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6273 - val_logLik: -21.9875
# Epoch 1906/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.8202 - val_logLik: -22.4843
# Epoch 1907/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.4968 - val_logLik: -22.2285
# Epoch 1908/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4254 - val_logLik: -22.2961
# Epoch 1909/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -49.1366 - val_logLik: -21.1223
# Epoch 1910/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.2486 - val_logLik: -20.3047
# Epoch 1911/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.9229 - val_logLik: -22.4939
# Epoch 1912/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1981 - val_logLik: -22.2977
# Epoch 1913/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4901 - val_logLik: -22.0457
# Epoch 1914/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.6139 - val_logLik: -21.2499
# Epoch 1915/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.5761 - val_logLik: -21.5105
# Epoch 1916/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.6182 - val_logLik: -22.2727
# Epoch 1917/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -49.0080 - val_logLik: -21.9613
# Epoch 1918/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.9494 - val_logLik: -21.8474
# Epoch 1919/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.0704 - val_logLik: -20.2624
# Epoch 1920/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.0581 - val_logLik: -21.0429
# Epoch 1921/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.7573 - val_logLik: -20.2750
# Epoch 1922/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.2213 - val_logLik: -20.4598
# Epoch 1923/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4236 - val_logLik: -21.6395
# Epoch 1924/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -45.8109 - val_logLik: -21.3010
# Epoch 1925/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.1811 - val_logLik: -20.3659
# Epoch 1926/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.2643 - val_logLik: -18.1415
# Epoch 1927/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.8576 - val_logLik: -22.1311
# Epoch 1928/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.1635 - val_logLik: -22.0384
# Epoch 1929/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4291 - val_logLik: -20.0381
# Epoch 1930/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.9602 - val_logLik: -19.8536
# Epoch 1931/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4486 - val_logLik: -21.5415
# Epoch 1932/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.5148 - val_logLik: -21.8297
# Epoch 1933/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.1530 - val_logLik: -21.1215
# Epoch 1934/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.9815 - val_logLik: -22.3696
# Epoch 1935/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.8334 - val_logLik: -20.7234
# Epoch 1936/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.5358 - val_logLik: -22.1063
# Epoch 1937/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.5258 - val_logLik: -22.2284
# Epoch 1938/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.9121 - val_logLik: -22.1939
# Epoch 1939/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.2992 - val_logLik: -22.0204
# Epoch 1940/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -45.3889 - val_logLik: -19.7114
# Epoch 1941/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -43.4285 - val_logLik: -22.3343
# Epoch 1942/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.9948 - val_logLik: -21.5777
# Epoch 1943/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.3521 - val_logLik: -21.5716
# Epoch 1944/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.7539 - val_logLik: -21.2258
# Epoch 1945/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.3900 - val_logLik: -22.0491
# Epoch 1946/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.6074 - val_logLik: -20.4366
# Epoch 1947/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6864 - val_logLik: -22.2444
# Epoch 1948/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.1528 - val_logLik: -19.2092
# Epoch 1949/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.9724 - val_logLik: -21.9764
# Epoch 1950/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.9667 - val_logLik: -19.8887
# Epoch 1951/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.2744 - val_logLik: -20.4595
# Epoch 1952/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.3286 - val_logLik: -21.3766
# Epoch 1953/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.2297 - val_logLik: -22.1100
# Epoch 1954/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.1464 - val_logLik: -19.8063
# Epoch 1955/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6623 - val_logLik: -18.6280
# Epoch 1956/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.4186 - val_logLik: -17.9420
# Epoch 1957/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.6086 - val_logLik: -21.8758
# Epoch 1958/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.8543 - val_logLik: -21.9601
# Epoch 1959/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.6877 - val_logLik: -20.2926
# Epoch 1960/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.7062 - val_logLik: -22.1864
# Epoch 1961/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.7596 - val_logLik: -21.5537
# Epoch 1962/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.2112 - val_logLik: -20.4266
# Epoch 1963/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1136 - val_logLik: -21.1099
# Epoch 1964/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.7764 - val_logLik: -21.9235
# Epoch 1965/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.9331 - val_logLik: -20.9782
# Epoch 1966/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.9175 - val_logLik: -21.2621
# Epoch 1967/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.6152 - val_logLik: -20.8891
# Epoch 1968/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4235 - val_logLik: -19.5733
# Epoch 1969/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.1760 - val_logLik: -21.1097
# Epoch 1970/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4687 - val_logLik: -17.5173
# Epoch 1971/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.8434 - val_logLik: -21.3407
# Epoch 1972/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -45.4519 - val_logLik: -21.9520
# Epoch 1973/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4574 - val_logLik: -20.9318
# Epoch 1974/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.1741 - val_logLik: -16.9827
# Epoch 1975/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.6568 - val_logLik: -20.8574
# Epoch 1976/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.1580 - val_logLik: -21.8191
# Epoch 1977/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -47.3130 - val_logLik: -20.5995
# Epoch 1978/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.2881 - val_logLik: -21.8408
# Epoch 1979/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1228 - val_logLik: -22.2043
# Epoch 1980/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.7227 - val_logLik: -21.8184
# Epoch 1981/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.6125 - val_logLik: -17.7280
# Epoch 1982/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -46.5721 - val_logLik: -21.2713
# Epoch 1983/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4091 - val_logLik: -20.2555
# Epoch 1984/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.7003 - val_logLik: -21.7663
# Epoch 1985/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.1314 - val_logLik: -20.1294
# Epoch 1986/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.0753 - val_logLik: -21.4282
# Epoch 1987/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.3776 - val_logLik: -20.5651
# Epoch 1988/10000
# 22/22 [==============================] - 0s 4ms/step - logLik: -48.3635 - val_logLik: -20.5792
# Epoch 1989/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.2459 - val_logLik: -22.4736
# Epoch 1990/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.2945 - val_logLik: -22.1554
# Epoch 1991/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.4573 - val_logLik: -20.9153
# Epoch 1992/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.4575 - val_logLik: -20.1883
# Epoch 1993/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.0144 - val_logLik: -20.0900
# Epoch 1994/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -42.5219 - val_logLik: -19.4492
# Epoch 1995/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -45.6735 - val_logLik: -19.0230
# Epoch 1996/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.2293 - val_logLik: -22.1957
# Epoch 1997/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.4330 - val_logLik: -22.1639
# Epoch 1998/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.0306 - val_logLik: -21.9721
# Epoch 1999/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -47.3364 - val_logLik: -22.0081
# Epoch 2000/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -45.3499 - val_logLik: -22.4646
# Epoch 2001/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.6828 - val_logLik: -21.9842
# Epoch 2002/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.4332 - val_logLik: -21.6529
# Epoch 2003/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.7024 - val_logLik: -22.0488
# Epoch 2004/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -48.9522 - val_logLik: -20.5411
# Epoch 2005/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.2403 - val_logLik: -19.2863
# Epoch 2006/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -45.4570 - val_logLik: -21.5717
# Epoch 2007/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -47.3823 - val_logLik: -21.0092
# Epoch 2008/10000
# 22/22 [==============================] - 0s 6ms/step - logLik: -46.8489 - val_logLik: -20.1416
# Epoch 2009/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.5032 - val_logLik: -21.2201
# Epoch 2010/10000
# 22/22 [==============================] - 0s 5ms/step - logLik: -48.1667 - val_logLik: -19.6582
# Epoch 2011/10000
# 22/22 [==============================] - 0s 7ms/step - logLik: -49.2169 - val_logLik: -21.0354

# %%
plt.figure(figsize=set_size(textwidth))
plt.plot(hist.history['logLik'], label='train')
plt.plot(hist.history['val_logLik'], label='valid')
plt.legend()

# %% [markdown]
# ## plot transformation function
# This weight initialization does function and our NN converged

# %%
yy = np.linspace(-5,5,100)
xx = np.zeros((yy.shape[0], 8))
z = neat_model.predict((xx,yy))
plt.figure(figsize=set_size(textwidth))
plt.title(r"Transformation function with initialisation $U(0, \text{sqrt}(6/(\text{fan}_{in}+\text{fan}_{out}))$")
plt.xlabel(r"$y$")
plt.ylabel(r"$g(y|x=0)$")
plt.scatter(yy, z)
plt.savefig("images/initialisation_xavier_uniform+.pdf")
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %% [markdown]
#  we also see that the data is almost transformed into a Normal distribution

# %%
yy = load_data(data_path)['y_train']
xx = load_data(data_path)['x_train']
z = neat_model.predict((xx,yy))

plt.figure(figsize=set_size(textwidth))
plt.hist(z, bins=20, label="y transformed")
plt.hist(load_data(data_path)['y_train'], bins=20, label="y")
plt.legend()
# Out:
# 22/22 [==============================] - 0s 2ms/step

# %%
from scipy import stats
num_bins=30

plt.figure(figsize=set_size(textwidth))
plt.hist(z, bins=num_bins, alpha=0.8, density=True)

yy = np.linspace(-4, 4, 1000)
bin_width = (z.max() - z.min()) / num_bins
plt.plot(yy, stats.norm(z.mean(), z.std()).pdf(yy))

# %% [markdown]
# # Train realy large model (y_net = 100 neurons with 10 Layers) and with adapted Xavier initialisation

# %%
def constraint_xavier_p_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    # limit = np.sqrt(6. / (fan_in+fan_out))
    limit = np.sqrt(9. / (np.max([fan_in, fan_out])**2))
    return tf.random.uniform(shape, minval=0, maxval=limit, dtype=dtype)

# %%
data_path = "energy"
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=constraint_xavier_p_init)
hp_param['net_y_size_trunk_args']['y_base_units'] = [100]*10
neat_model, hist = fit_func(hp_param, data_path, fast=False)
# Out:
# Epoch 1/10000
# 22/22 [==============================] - 1s 11ms/step - logLik: 69.4956 - val_logLik: 16.2098
# Epoch 2/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 26.6909 - val_logLik: 4.5217
# Epoch 3/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 14.5212 - val_logLik: 2.8319
# Epoch 4/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 8.8021 - val_logLik: 4.4586
# Epoch 5/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 8.9572 - val_logLik: 1.7342
# Epoch 6/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 7.1973 - val_logLik: 0.4965
# Epoch 7/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 1.9101 - val_logLik: 2.7019
# Epoch 8/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 1.1463 - val_logLik: 3.7266
# Epoch 9/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 3.4602 - val_logLik: -1.1563
# Epoch 10/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -0.4266 - val_logLik: 5.0667
# Epoch 11/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 4.3818 - val_logLik: -0.9986
# Epoch 12/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 0.7797 - val_logLik: -0.9763
# Epoch 13/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -0.8152 - val_logLik: 0.1953
# Epoch 14/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 2.8025 - val_logLik: 1.1001
# Epoch 15/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 2.2068 - val_logLik: 2.2951
# Epoch 16/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -1.0802 - val_logLik: 3.2792
# Epoch 17/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -0.0776 - val_logLik: -0.1049
# Epoch 18/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -1.5345 - val_logLik: 0.4745
# Epoch 19/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -3.1472 - val_logLik: -1.2881
# Epoch 20/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 0.9794 - val_logLik: -0.7865
# Epoch 21/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.0173 - val_logLik: 0.9573
# Epoch 22/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -1.7706 - val_logLik: 0.3458
# Epoch 23/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.0082 - val_logLik: 0.9874
# Epoch 24/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.1406 - val_logLik: -1.7215
# Epoch 25/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.9622 - val_logLik: -1.1735
# Epoch 26/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.4401 - val_logLik: -0.7482
# Epoch 27/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.5734 - val_logLik: -1.0310
# Epoch 28/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -3.4685 - val_logLik: -1.4140
# Epoch 29/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.7623 - val_logLik: -1.7587
# Epoch 30/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.8251 - val_logLik: -1.2121
# Epoch 31/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -6.4281 - val_logLik: -0.9659
# Epoch 32/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -6.3222 - val_logLik: 0.3842
# Epoch 33/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -3.7250 - val_logLik: 0.1734
# Epoch 34/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -3.4212 - val_logLik: -0.7281
# Epoch 35/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.9631 - val_logLik: -0.8171
# Epoch 36/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.3050 - val_logLik: -0.8178
# Epoch 37/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.1287 - val_logLik: 1.6924
# Epoch 38/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -1.9756 - val_logLik: 4.0802
# Epoch 39/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.3626 - val_logLik: -0.5655
# Epoch 40/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -6.5039 - val_logLik: -0.0017
# Epoch 41/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.2981 - val_logLik: -1.3868
# Epoch 42/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.2689 - val_logLik: -1.4092
# Epoch 43/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.0889 - val_logLik: -0.7360
# Epoch 44/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.8734 - val_logLik: -1.7309
# Epoch 45/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: 1.1397 - val_logLik: 3.6125
# Epoch 46/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -3.8170 - val_logLik: 4.8477
# Epoch 47/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.0922 - val_logLik: -1.3081
# Epoch 48/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.4587 - val_logLik: -1.2721
# Epoch 49/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.7395 - val_logLik: -1.0436
# Epoch 50/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.2369 - val_logLik: 0.3002
# Epoch 51/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.1321 - val_logLik: -1.3385
# Epoch 52/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.4526 - val_logLik: -1.8154
# Epoch 53/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.8320 - val_logLik: -1.3347
# Epoch 54/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.2887 - val_logLik: -1.3460
# Epoch 55/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.9679 - val_logLik: -1.0596
# Epoch 56/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.9845 - val_logLik: -1.6946
# Epoch 57/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.7953 - val_logLik: -0.5185
# Epoch 58/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.5124 - val_logLik: -0.1704
# Epoch 59/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.4085 - val_logLik: -1.0368
# Epoch 60/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.7617 - val_logLik: 0.2690
# Epoch 61/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.0054 - val_logLik: -1.2320
# Epoch 62/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.0061 - val_logLik: 0.5349
# Epoch 63/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.7500 - val_logLik: 1.0651
# Epoch 64/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.8663 - val_logLik: -1.3967
# Epoch 65/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.2264 - val_logLik: 1.8073
# Epoch 66/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.7594 - val_logLik: -0.7765
# Epoch 67/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.0757 - val_logLik: 1.3061
# Epoch 68/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.4126 - val_logLik: -0.9496
# Epoch 69/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.9678 - val_logLik: -1.4309
# Epoch 70/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.8567 - val_logLik: -0.8321
# Epoch 71/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.8123 - val_logLik: -1.8509
# Epoch 72/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.6865 - val_logLik: 0.9682
# Epoch 73/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -4.6845 - val_logLik: 6.5099
# Epoch 74/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.4633 - val_logLik: 1.2969
# Epoch 75/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -5.4761 - val_logLik: 3.5079
# Epoch 76/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.8532 - val_logLik: -1.3458
# Epoch 77/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.4443 - val_logLik: -2.2711
# Epoch 78/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.4006 - val_logLik: -2.4318
# Epoch 79/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.8885 - val_logLik: -2.3326
# Epoch 80/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.3890 - val_logLik: -2.2458
# Epoch 81/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.6761 - val_logLik: -0.0937
# Epoch 82/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.1975 - val_logLik: -0.8305
# Epoch 83/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.7890 - val_logLik: -2.3696
# Epoch 84/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.6428 - val_logLik: -2.7660
# Epoch 85/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.8389 - val_logLik: -1.8155
# Epoch 86/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.2136 - val_logLik: -2.2045
# Epoch 87/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.0825 - val_logLik: -1.7817
# Epoch 88/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.1288 - val_logLik: -1.5191
# Epoch 89/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.9698 - val_logLik: -0.5699
# Epoch 90/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.4346 - val_logLik: 0.7424
# Epoch 91/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.2307 - val_logLik: -1.7917
# Epoch 92/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.2562 - val_logLik: -2.4428
# Epoch 93/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.6865 - val_logLik: -2.4116
# Epoch 94/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -7.9914 - val_logLik: -2.6702
# Epoch 95/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5658 - val_logLik: -2.2052
# Epoch 96/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.6247 - val_logLik: -2.6194
# Epoch 97/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5346 - val_logLik: 0.6791
# Epoch 98/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.9078 - val_logLik: -1.8076
# Epoch 99/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.8198 - val_logLik: 0.3056
# Epoch 100/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -6.0768 - val_logLik: -2.7717
# Epoch 101/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.4851 - val_logLik: -2.2468
# Epoch 102/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.6053 - val_logLik: -1.9711
# Epoch 103/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.5896 - val_logLik: -1.6732
# Epoch 104/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.7123 - val_logLik: -2.5278
# Epoch 105/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.8540 - val_logLik: -2.5265
# Epoch 106/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.8191 - val_logLik: -2.5567
# Epoch 107/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.7970 - val_logLik: -0.9111
# Epoch 108/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.9731 - val_logLik: -2.0676
# Epoch 109/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5469 - val_logLik: -2.5498
# Epoch 110/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.7708 - val_logLik: -3.0364
# Epoch 111/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.1184 - val_logLik: -0.5000
# Epoch 112/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.7607 - val_logLik: -2.5329
# Epoch 113/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.0846 - val_logLik: 2.0630
# Epoch 114/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.1582 - val_logLik: -2.4935
# Epoch 115/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5950 - val_logLik: -1.4993
# Epoch 116/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.6938 - val_logLik: -0.6382
# Epoch 117/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.3600 - val_logLik: -2.0903
# Epoch 118/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.9578 - val_logLik: -2.0608
# Epoch 119/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.9269 - val_logLik: -2.1876
# Epoch 120/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.8271 - val_logLik: -2.7970
# Epoch 121/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.2880 - val_logLik: 0.5261
# Epoch 122/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.8375 - val_logLik: -1.3031
# Epoch 123/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.2336 - val_logLik: -2.4195
# Epoch 124/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.1465 - val_logLik: -3.1129
# Epoch 125/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.6846 - val_logLik: -1.6721
# Epoch 126/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.2254 - val_logLik: -2.8167
# Epoch 127/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5772 - val_logLik: -2.3624
# Epoch 128/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.3233 - val_logLik: -2.7632
# Epoch 129/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.4591 - val_logLik: -1.4150
# Epoch 130/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.9326 - val_logLik: -1.7923
# Epoch 131/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5405 - val_logLik: -3.1822
# Epoch 132/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.8167 - val_logLik: 3.5144
# Epoch 133/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.4929 - val_logLik: -1.5955
# Epoch 134/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5857 - val_logLik: -2.7750
# Epoch 135/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.7326 - val_logLik: -1.4887
# Epoch 136/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.2806 - val_logLik: -1.2257
# Epoch 137/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0179 - val_logLik: -2.7921
# Epoch 138/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.1839 - val_logLik: 0.4227
# Epoch 139/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.7272 - val_logLik: -3.0722
# Epoch 140/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.4786 - val_logLik: -2.9753
# Epoch 141/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.3115 - val_logLik: -2.0616
# Epoch 142/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0755 - val_logLik: -2.7975
# Epoch 143/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.2031 - val_logLik: -1.7503
# Epoch 144/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.8461 - val_logLik: -2.6215
# Epoch 145/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5115 - val_logLik: -2.0666
# Epoch 146/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.5999 - val_logLik: 0.4741
# Epoch 147/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.0702 - val_logLik: -2.9623
# Epoch 148/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8183 - val_logLik: -3.0916
# Epoch 149/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.1526 - val_logLik: -1.2660
# Epoch 150/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5964 - val_logLik: -2.6326
# Epoch 151/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.5017 - val_logLik: -2.2620
# Epoch 152/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8371 - val_logLik: -2.8754
# Epoch 153/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9695 - val_logLik: -3.0284
# Epoch 154/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8629 - val_logLik: -2.6392
# Epoch 155/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0030 - val_logLik: -1.8892
# Epoch 156/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.1747 - val_logLik: -2.6302
# Epoch 157/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.4584 - val_logLik: -1.5594
# Epoch 158/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6951 - val_logLik: -2.3192
# Epoch 159/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.7305 - val_logLik: -3.0596
# Epoch 160/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6996 - val_logLik: -2.5617
# Epoch 161/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.0014 - val_logLik: -3.2091
# Epoch 162/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8265 - val_logLik: -2.0627
# Epoch 163/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.1247 - val_logLik: -3.0359
# Epoch 164/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.0295 - val_logLik: -1.9347
# Epoch 165/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.7869 - val_logLik: -3.1860
# Epoch 166/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.2593 - val_logLik: -2.2798
# Epoch 167/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.1865 - val_logLik: -1.7211
# Epoch 168/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9898 - val_logLik: -2.2277
# Epoch 169/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.5024 - val_logLik: -1.8381
# Epoch 170/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.3933 - val_logLik: -2.7350
# Epoch 171/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.4022 - val_logLik: -2.6175
# Epoch 172/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.0838 - val_logLik: -1.5184
# Epoch 173/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.7306 - val_logLik: -3.2678
# Epoch 174/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8531 - val_logLik: -3.3574
# Epoch 175/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.2807 - val_logLik: -0.7051
# Epoch 176/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.5671 - val_logLik: -1.8534
# Epoch 177/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.6159 - val_logLik: 0.0040
# Epoch 178/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.2267 - val_logLik: 1.9515
# Epoch 179/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -8.9132 - val_logLik: -0.5307
# Epoch 180/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0914 - val_logLik: -3.3440
# Epoch 181/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9216 - val_logLik: -3.2854
# Epoch 182/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.7479 - val_logLik: -1.3641
# Epoch 183/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.2095 - val_logLik: -2.9593
# Epoch 184/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.3750 - val_logLik: -3.2598
# Epoch 185/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.3545 - val_logLik: -2.6905
# Epoch 186/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.2133 - val_logLik: -3.1990
# Epoch 187/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6069 - val_logLik: -3.2207
# Epoch 188/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5375 - val_logLik: -3.2011
# Epoch 189/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8672 - val_logLik: -3.2151
# Epoch 190/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6639 - val_logLik: -2.9371
# Epoch 191/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.8151 - val_logLik: -2.2426
# Epoch 192/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.0667 - val_logLik: -1.3583
# Epoch 193/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.7314 - val_logLik: -1.9422
# Epoch 194/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.5615 - val_logLik: -2.6208
# Epoch 195/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.2020 - val_logLik: -3.0967
# Epoch 196/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.6941 - val_logLik: -2.0977
# Epoch 197/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.3431 - val_logLik: -3.2451
# Epoch 198/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.3680 - val_logLik: 0.4565
# Epoch 199/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5105 - val_logLik: -2.7596
# Epoch 200/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5974 - val_logLik: -2.9773
# Epoch 201/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5934 - val_logLik: -3.3193
# Epoch 202/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.3110 - val_logLik: -3.3411
# Epoch 203/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.7227 - val_logLik: -0.4747
# Epoch 204/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.3222 - val_logLik: -2.6893
# Epoch 205/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6981 - val_logLik: -3.5690
# Epoch 206/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.3653 - val_logLik: -1.0219
# Epoch 207/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.7369 - val_logLik: -1.8422
# Epoch 208/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.6282 - val_logLik: -2.4590
# Epoch 209/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.3924 - val_logLik: -3.0430
# Epoch 210/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.0381 - val_logLik: -3.4965
# Epoch 211/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.3551 - val_logLik: -3.2234
# Epoch 212/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.0044 - val_logLik: -2.3465
# Epoch 213/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.2266 - val_logLik: -3.5158
# Epoch 214/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8660 - val_logLik: -1.1644
# Epoch 215/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.2224 - val_logLik: -1.5210
# Epoch 216/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -9.4769 - val_logLik: -1.2726
# Epoch 217/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.5155 - val_logLik: -2.9814
# Epoch 218/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0953 - val_logLik: -2.2135
# Epoch 219/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.4497 - val_logLik: -2.4356
# Epoch 220/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9771 - val_logLik: -3.6002
# Epoch 221/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9280 - val_logLik: -3.2067
# Epoch 222/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4781 - val_logLik: -3.1711
# Epoch 223/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9881 - val_logLik: -3.3267
# Epoch 224/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.9696 - val_logLik: -3.4823
# Epoch 225/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9028 - val_logLik: -3.5972
# Epoch 226/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4154 - val_logLik: -3.1320
# Epoch 227/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4483 - val_logLik: -1.9420
# Epoch 228/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.7511 - val_logLik: -2.5368
# Epoch 229/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9372 - val_logLik: -2.7170
# Epoch 230/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.1279 - val_logLik: -3.5086
# Epoch 231/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9923 - val_logLik: -1.9568
# Epoch 232/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.2960 - val_logLik: -2.5719
# Epoch 233/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6320 - val_logLik: -2.9654
# Epoch 234/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5167 - val_logLik: -2.0889
# Epoch 235/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.4953 - val_logLik: -0.1798
# Epoch 236/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8817 - val_logLik: -3.8966
# Epoch 237/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6148 - val_logLik: -3.4407
# Epoch 238/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4905 - val_logLik: -3.7897
# Epoch 239/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5122 - val_logLik: -3.4715
# Epoch 240/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9876 - val_logLik: -3.2499
# Epoch 241/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.4628 - val_logLik: -0.9477
# Epoch 242/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5865 - val_logLik: -3.7591
# Epoch 243/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.1409 - val_logLik: -3.0675
# Epoch 244/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6149 - val_logLik: -3.3399
# Epoch 245/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.2747 - val_logLik: -3.4882
# Epoch 246/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6101 - val_logLik: -3.9950
# Epoch 247/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.5484 - val_logLik: -3.9893
# Epoch 248/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4010 - val_logLik: -3.7668
# Epoch 249/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4210 - val_logLik: -3.6465
# Epoch 250/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -10.5703 - val_logLik: 1.0115
# Epoch 251/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.5820 - val_logLik: -3.4533
# Epoch 252/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.3699 - val_logLik: -3.8946
# Epoch 253/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9081 - val_logLik: -4.0953
# Epoch 254/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5969 - val_logLik: -3.0608
# Epoch 255/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9803 - val_logLik: -2.9215
# Epoch 256/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.5480 - val_logLik: -1.8257
# Epoch 257/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.2521 - val_logLik: -3.8376
# Epoch 258/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6039 - val_logLik: -3.6482
# Epoch 259/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6077 - val_logLik: -3.4072
# Epoch 260/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.9851 - val_logLik: -2.2247
# Epoch 261/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9321 - val_logLik: -1.7436
# Epoch 262/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.8858 - val_logLik: -2.6147
# Epoch 263/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6540 - val_logLik: -0.8675
# Epoch 264/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.9748 - val_logLik: -3.5542
# Epoch 265/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4032 - val_logLik: -2.5308
# Epoch 266/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6716 - val_logLik: -3.9208
# Epoch 267/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.0754 - val_logLik: -3.6004
# Epoch 268/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1623 - val_logLik: -3.1467
# Epoch 269/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6146 - val_logLik: -3.6592
# Epoch 270/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.2332 - val_logLik: -4.1930
# Epoch 271/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4103 - val_logLik: -3.9895
# Epoch 272/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1206 - val_logLik: -4.1009
# Epoch 273/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4794 - val_logLik: -2.2846
# Epoch 274/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.8788 - val_logLik: -2.8212
# Epoch 275/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.3153 - val_logLik: -3.5466
# Epoch 276/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.0008 - val_logLik: -3.1175
# Epoch 277/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.7139 - val_logLik: -3.6007
# Epoch 278/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.7259 - val_logLik: -3.2527
# Epoch 279/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9658 - val_logLik: -2.2606
# Epoch 280/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6920 - val_logLik: -4.0774
# Epoch 281/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4023 - val_logLik: -3.7248
# Epoch 282/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5956 - val_logLik: -3.5078
# Epoch 283/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7496 - val_logLik: -3.6742
# Epoch 284/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.2737 - val_logLik: -3.9376
# Epoch 285/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.8978 - val_logLik: -3.1853
# Epoch 286/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.6472 - val_logLik: 1.0835
# Epoch 287/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8311 - val_logLik: -3.7270
# Epoch 288/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6368 - val_logLik: -1.8380
# Epoch 289/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.0712 - val_logLik: -3.7641
# Epoch 290/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1094 - val_logLik: -3.5442
# Epoch 291/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6837 - val_logLik: -3.6361
# Epoch 292/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4565 - val_logLik: -2.4021
# Epoch 293/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9004 - val_logLik: -4.0057
# Epoch 294/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7109 - val_logLik: -3.7359
# Epoch 295/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.2799 - val_logLik: -2.6472
# Epoch 296/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.2021 - val_logLik: -3.3737
# Epoch 297/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9302 - val_logLik: -3.5175
# Epoch 298/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5331 - val_logLik: -2.6940
# Epoch 299/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.0583 - val_logLik: -3.9850
# Epoch 300/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9565 - val_logLik: -2.9045
# Epoch 301/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5428 - val_logLik: -3.6900
# Epoch 302/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.8227 - val_logLik: -2.2442
# Epoch 303/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.2125 - val_logLik: -3.8488
# Epoch 304/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.4514 - val_logLik: -3.9415
# Epoch 305/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.7914 - val_logLik: -3.2483
# Epoch 306/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.0395 - val_logLik: -2.2767
# Epoch 307/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.8312 - val_logLik: -3.9186
# Epoch 308/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.9348 - val_logLik: -4.0756
# Epoch 309/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6705 - val_logLik: -4.1485
# Epoch 310/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.4418 - val_logLik: -4.0430
# Epoch 311/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.4445 - val_logLik: -4.0321
# Epoch 312/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.7271 - val_logLik: -4.0791
# Epoch 313/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.8453 - val_logLik: -3.9867
# Epoch 314/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.3658 - val_logLik: -1.6589
# Epoch 315/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9794 - val_logLik: -3.1710
# Epoch 316/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7123 - val_logLik: -4.1547
# Epoch 317/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.4686 - val_logLik: -2.1345
# Epoch 318/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.3470 - val_logLik: -2.4421
# Epoch 319/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.6379 - val_logLik: -2.7944
# Epoch 320/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.7869 - val_logLik: -2.0424
# Epoch 321/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1214 - val_logLik: -4.2121
# Epoch 322/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6784 - val_logLik: -3.7116
# Epoch 323/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7061 - val_logLik: -3.7445
# Epoch 324/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1833 - val_logLik: -2.3946
# Epoch 325/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7692 - val_logLik: -2.4311
# Epoch 326/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -11.9905 - val_logLik: 0.2788
# Epoch 327/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.2796 - val_logLik: -4.1063
# Epoch 328/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4590 - val_logLik: -3.5526
# Epoch 329/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.4037 - val_logLik: -2.0651
# Epoch 330/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.9514 - val_logLik: -3.6293
# Epoch 331/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3085 - val_logLik: -3.7708
# Epoch 332/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.0316 - val_logLik: -4.0304
# Epoch 333/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.0974 - val_logLik: -3.5341
# Epoch 334/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -12.3352 - val_logLik: -4.0081
# Epoch 335/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.3289 - val_logLik: -3.7475
# Epoch 336/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.7131 - val_logLik: -4.4481
# Epoch 337/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.6012 - val_logLik: -4.6458
# Epoch 338/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5897 - val_logLik: -4.3617
# Epoch 339/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.8770 - val_logLik: -3.8017
# Epoch 340/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6670 - val_logLik: -4.5592
# Epoch 341/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3333 - val_logLik: -4.3908
# Epoch 342/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.7225 - val_logLik: -4.6893
# Epoch 343/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5609 - val_logLik: -4.0466
# Epoch 344/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2759 - val_logLik: -4.1886
# Epoch 345/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6994 - val_logLik: -4.4321
# Epoch 346/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.1073 - val_logLik: -4.0408
# Epoch 347/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.9869 - val_logLik: -4.2806
# Epoch 348/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.4633 - val_logLik: -4.6499
# Epoch 349/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2658 - val_logLik: -4.6799
# Epoch 350/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.4840 - val_logLik: -3.9336
# Epoch 351/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.7625 - val_logLik: -4.5638
# Epoch 352/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.4556 - val_logLik: -0.9240
# Epoch 353/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.8300 - val_logLik: -4.0308
# Epoch 354/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -13.9645 - val_logLik: -0.0988
# Epoch 355/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8445 - val_logLik: -4.2025
# Epoch 356/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.0271 - val_logLik: -3.8335
# Epoch 357/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.8819 - val_logLik: -4.0218
# Epoch 358/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.9183 - val_logLik: -4.3153
# Epoch 359/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.4008 - val_logLik: -4.5781
# Epoch 360/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.0595 - val_logLik: -3.8093
# Epoch 361/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1927 - val_logLik: -4.8042
# Epoch 362/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.8928 - val_logLik: -3.8901
# Epoch 363/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1045 - val_logLik: -3.9437
# Epoch 364/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.2593 - val_logLik: -3.2918
# Epoch 365/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4315 - val_logLik: -3.8827
# Epoch 366/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5376 - val_logLik: -3.7468
# Epoch 367/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2684 - val_logLik: -4.1359
# Epoch 368/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.7222 - val_logLik: -4.6137
# Epoch 369/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.9879 - val_logLik: -4.2264
# Epoch 370/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.2392 - val_logLik: -3.1132
# Epoch 371/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.7207 - val_logLik: -4.7622
# Epoch 372/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2740 - val_logLik: -4.1843
# Epoch 373/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6189 - val_logLik: -3.7372
# Epoch 374/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.6255 - val_logLik: -4.9136
# Epoch 375/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.1022 - val_logLik: -2.6523
# Epoch 376/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5720 - val_logLik: -4.4850
# Epoch 377/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.9518 - val_logLik: -4.0139
# Epoch 378/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.5212 - val_logLik: -3.5695
# Epoch 379/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2394 - val_logLik: -2.8161
# Epoch 380/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1308 - val_logLik: -4.5235
# Epoch 381/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.8428 - val_logLik: -2.9946
# Epoch 382/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5534 - val_logLik: -4.8181
# Epoch 383/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.1036 - val_logLik: -3.5795
# Epoch 384/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5961 - val_logLik: -4.1292
# Epoch 385/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1104 - val_logLik: -4.0308
# Epoch 386/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.6800 - val_logLik: -4.7361
# Epoch 387/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2882 - val_logLik: -4.2495
# Epoch 388/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5693 - val_logLik: -4.9392
# Epoch 389/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1864 - val_logLik: -4.1637
# Epoch 390/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2510 - val_logLik: -3.2138
# Epoch 391/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2389 - val_logLik: -1.6600
# Epoch 392/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.5233 - val_logLik: -2.9569
# Epoch 393/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.5981 - val_logLik: -4.9962
# Epoch 394/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3506 - val_logLik: -4.7477
# Epoch 395/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.6481 - val_logLik: -4.2246
# Epoch 396/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3122 - val_logLik: -4.2676
# Epoch 397/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.5076 - val_logLik: -1.9732
# Epoch 398/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.1977 - val_logLik: -4.6311
# Epoch 399/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5694 - val_logLik: -4.3563
# Epoch 400/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3841 - val_logLik: -4.4531
# Epoch 401/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6756 - val_logLik: -3.0834
# Epoch 402/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.4001 - val_logLik: -5.1606
# Epoch 403/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.9920 - val_logLik: -4.3580
# Epoch 404/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6179 - val_logLik: -3.0632
# Epoch 405/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.6202 - val_logLik: -4.4967
# Epoch 406/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.0210 - val_logLik: -4.1931
# Epoch 407/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.7690 - val_logLik: -4.8371
# Epoch 408/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.8365 - val_logLik: -4.6020
# Epoch 409/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.7771 - val_logLik: -5.3295
# Epoch 410/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.4995 - val_logLik: -4.8776
# Epoch 411/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -14.8626 - val_logLik: -0.3242
# Epoch 412/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2792 - val_logLik: -5.1732
# Epoch 413/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.6732 - val_logLik: -5.4141
# Epoch 414/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.8116 - val_logLik: -4.7648
# Epoch 415/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.7893 - val_logLik: -4.6219
# Epoch 416/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -17.6213 - val_logLik: -4.7463
# Epoch 417/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5871 - val_logLik: -5.1624
# Epoch 418/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.5351 - val_logLik: -3.7440
# Epoch 419/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.3086 - val_logLik: -4.1167
# Epoch 420/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.0956 - val_logLik: -5.0767
# Epoch 421/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.9156 - val_logLik: -5.0570
# Epoch 422/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.0606 - val_logLik: -4.1812
# Epoch 423/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.6075 - val_logLik: -3.3391
# Epoch 424/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.2768 - val_logLik: -4.6883
# Epoch 425/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.6672 - val_logLik: -3.2250
# Epoch 426/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.7590 - val_logLik: -2.4202
# Epoch 427/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.7334 - val_logLik: -4.1661
# Epoch 428/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.1208 - val_logLik: -5.2381
# Epoch 429/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.9622 - val_logLik: -2.0090
# Epoch 430/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.3389 - val_logLik: -4.9513
# Epoch 431/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.6450 - val_logLik: -5.4501
# Epoch 432/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.4348 - val_logLik: -5.5940
# Epoch 433/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -19.8549 - val_logLik: -5.3582
# Epoch 434/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.4797 - val_logLik: -5.2983
# Epoch 435/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -20.1428 - val_logLik: -5.0329
# Epoch 436/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -18.4428 - val_logLik: -3.3847
# Epoch 437/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -15.9972 - val_logLik: -1.9908
# Epoch 438/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -16.4227 - val_logLik: -3.7165
# Epoch 439/10000
# ...
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.4352 - val_logLik: -17.6777
# Epoch 2280/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.4494 - val_logLik: -17.3358
# Epoch 2281/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7103 - val_logLik: -17.9968
# Epoch 2282/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.9748 - val_logLik: -15.2374
# Epoch 2283/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.4450 - val_logLik: -17.2521
# Epoch 2284/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.1486 - val_logLik: -18.0304
# Epoch 2285/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.0324 - val_logLik: -17.9115
# Epoch 2286/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.1706 - val_logLik: -12.2606
# Epoch 2287/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2071 - val_logLik: -17.6680
# Epoch 2288/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.3880 - val_logLik: -18.1044
# Epoch 2289/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.7597 - val_logLik: -16.1112
# Epoch 2290/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.1848 - val_logLik: -16.9688
# Epoch 2291/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.9755 - val_logLik: -17.7325
# Epoch 2292/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.1505 - val_logLik: -17.7735
# Epoch 2293/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.5772 - val_logLik: -16.1728
# Epoch 2294/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.3250 - val_logLik: -17.1277
# Epoch 2295/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.7190 - val_logLik: -18.0761
# Epoch 2296/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2606 - val_logLik: -14.5386
# Epoch 2297/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -38.2290 - val_logLik: -17.8803
# Epoch 2298/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.5350 - val_logLik: -17.7508
# Epoch 2299/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2948 - val_logLik: -18.2289
# Epoch 2300/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.8064 - val_logLik: -17.0080
# Epoch 2301/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.8174 - val_logLik: -17.1949
# Epoch 2302/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.6478 - val_logLik: -17.8587
# Epoch 2303/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.7281 - val_logLik: -15.7779
# Epoch 2304/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.5903 - val_logLik: -18.1782
# Epoch 2305/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.0142 - val_logLik: -16.7239
# Epoch 2306/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.5555 - val_logLik: -18.2145
# Epoch 2307/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7948 - val_logLik: -18.2582
# Epoch 2308/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.9926 - val_logLik: -17.4437
# Epoch 2309/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -34.1405 - val_logLik: -13.9437
# Epoch 2310/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.6479 - val_logLik: -14.8126
# Epoch 2311/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7785 - val_logLik: -17.6435
# Epoch 2312/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.1494 - val_logLik: -16.4406
# Epoch 2313/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.8897 - val_logLik: -16.9358
# Epoch 2314/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.0858 - val_logLik: -18.2043
# Epoch 2315/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.8550 - val_logLik: -15.9443
# Epoch 2316/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.4441 - val_logLik: -18.1657
# Epoch 2317/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.2162 - val_logLik: -16.5565
# Epoch 2318/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2761 - val_logLik: -17.6661
# Epoch 2319/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.0621 - val_logLik: -16.7390
# Epoch 2320/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.8602 - val_logLik: -18.0360
# Epoch 2321/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.1370 - val_logLik: -18.5588
# Epoch 2322/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7717 - val_logLik: -15.7744
# Epoch 2323/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.8027 - val_logLik: -18.0809
# Epoch 2324/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.0288 - val_logLik: -17.4140
# Epoch 2325/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.4669 - val_logLik: -17.1876
# Epoch 2326/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7447 - val_logLik: -15.5522
# Epoch 2327/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7617 - val_logLik: -15.8455
# Epoch 2328/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.1413 - val_logLik: -14.8666
# Epoch 2329/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.0093 - val_logLik: -15.8007
# Epoch 2330/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2258 - val_logLik: -16.6929
# Epoch 2331/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.9770 - val_logLik: -16.0764
# Epoch 2332/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.0593 - val_logLik: -14.8021
# Epoch 2333/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7801 - val_logLik: -17.4083
# Epoch 2334/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.0935 - val_logLik: -17.4645
# Epoch 2335/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.9761 - val_logLik: -17.4843
# Epoch 2336/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.8198 - val_logLik: -16.2386
# Epoch 2337/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.2641 - val_logLik: -15.7317
# Epoch 2338/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.3082 - val_logLik: -16.6651
# Epoch 2339/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.0444 - val_logLik: -16.0733
# Epoch 2340/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.5791 - val_logLik: -14.5067
# Epoch 2341/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -34.3998 - val_logLik: -16.9819
# Epoch 2342/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.0164 - val_logLik: -15.2657
# Epoch 2343/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2859 - val_logLik: -14.7751
# Epoch 2344/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.3734 - val_logLik: -17.7795
# Epoch 2345/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.4278 - val_logLik: -17.6946
# Epoch 2346/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.7252 - val_logLik: -12.4556
# Epoch 2347/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -35.6162 - val_logLik: -16.7806
# Epoch 2348/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.8034 - val_logLik: -15.8406
# Epoch 2349/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7831 - val_logLik: -17.4038
# Epoch 2350/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.3003 - val_logLik: -17.3642
# Epoch 2351/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7778 - val_logLik: -15.8646
# Epoch 2352/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.5774 - val_logLik: -18.3042
# Epoch 2353/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.5432 - val_logLik: -13.5079
# Epoch 2354/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.0775 - val_logLik: -17.6920
# Epoch 2355/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7852 - val_logLik: -18.3312
# Epoch 2356/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.5334 - val_logLik: -17.1924
# Epoch 2357/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.6942 - val_logLik: -18.4125
# Epoch 2358/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.6009 - val_logLik: -17.9357
# Epoch 2359/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.9278 - val_logLik: -18.2275
# Epoch 2360/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.2342 - val_logLik: -16.8359
# Epoch 2361/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.6079 - val_logLik: -17.9145
# Epoch 2362/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -37.9819 - val_logLik: -10.5066
# Epoch 2363/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.4832 - val_logLik: -17.3388
# Epoch 2364/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.6429 - val_logLik: -13.7728
# Epoch 2365/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.6876 - val_logLik: -18.0153
# Epoch 2366/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.8489 - val_logLik: -17.9046
# Epoch 2367/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.6137 - val_logLik: -17.0715
# Epoch 2368/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.3205 - val_logLik: -15.8042
# Epoch 2369/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.0719 - val_logLik: -18.1610
# Epoch 2370/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.3343 - val_logLik: -16.3667
# Epoch 2371/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.2521 - val_logLik: -17.9560
# Epoch 2372/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7509 - val_logLik: -16.2404
# Epoch 2373/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.4743 - val_logLik: -18.3185
# Epoch 2374/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.2867 - val_logLik: -14.3648
# Epoch 2375/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.9998 - val_logLik: -17.5466
# Epoch 2376/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.4351 - val_logLik: -15.8416
# Epoch 2377/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -37.6130 - val_logLik: -16.6741
# Epoch 2378/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.0470 - val_logLik: -17.0875
# Epoch 2379/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.4109 - val_logLik: -17.8950
# Epoch 2380/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.7079 - val_logLik: -17.6150
# Epoch 2381/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.7906 - val_logLik: -18.1660
# Epoch 2382/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.2896 - val_logLik: -17.6814
# Epoch 2383/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.5630 - val_logLik: -11.6934
# Epoch 2384/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.8380 - val_logLik: -18.2015
# Epoch 2385/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.2732 - val_logLik: -18.3686
# Epoch 2386/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7885 - val_logLik: -16.2590
# Epoch 2387/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.6185 - val_logLik: -16.1730
# Epoch 2388/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.3661 - val_logLik: -17.1721
# Epoch 2389/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.8792 - val_logLik: -11.8225
# Epoch 2390/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.3844 - val_logLik: -15.0829
# Epoch 2391/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.5502 - val_logLik: -17.5985
# Epoch 2392/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.2695 - val_logLik: -14.3341
# Epoch 2393/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.4376 - val_logLik: -15.5507
# Epoch 2394/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -39.9094 - val_logLik: -15.4292
# Epoch 2395/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.3216 - val_logLik: -17.7084
# Epoch 2396/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.0923 - val_logLik: -15.7717
# Epoch 2397/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.2456 - val_logLik: -18.0226
# Epoch 2398/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.0631 - val_logLik: -17.0274
# Epoch 2399/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.6973 - val_logLik: -14.6040
# Epoch 2400/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.6507 - val_logLik: -17.8724
# Epoch 2401/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.4158 - val_logLik: -16.6383
# Epoch 2402/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.8496 - val_logLik: -18.4110
# Epoch 2403/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.9529 - val_logLik: -18.1228
# Epoch 2404/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.6378 - val_logLik: -17.0399
# Epoch 2405/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.1915 - val_logLik: -16.6139
# Epoch 2406/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.3919 - val_logLik: -11.6838
# Epoch 2407/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -40.8582 - val_logLik: -17.8576
# Epoch 2408/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.7394 - val_logLik: -17.0968
# Epoch 2409/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.2440 - val_logLik: -18.0327
# Epoch 2410/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.1974 - val_logLik: -16.0634
# Epoch 2411/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -41.3120 - val_logLik: -16.1685
# Epoch 2412/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.3505 - val_logLik: -18.2112
# Epoch 2413/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.7419 - val_logLik: -17.3311
# Epoch 2414/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.1154 - val_logLik: -15.2063
# Epoch 2415/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -43.1390 - val_logLik: -15.7556
# Epoch 2416/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.5046 - val_logLik: -18.1134
# Epoch 2417/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -42.7481 - val_logLik: -16.5577
# Epoch 2418/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -38.5185 - val_logLik: -15.2693
# Epoch 2419/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.3433 - val_logLik: -16.6092
# Epoch 2420/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -45.5746 - val_logLik: -15.8438
# Epoch 2421/10000
# 22/22 [==============================] - 0s 3ms/step - logLik: -44.7729 - val_logLik: -17.2942

# %%
plt.plot(hist.history['logLik'], label='train')
plt.plot(hist.history['val_logLik'], label='valid')
plt.legend()

# %% [markdown]
# ## plot transformation function
# With this setting it still breaks

# %%
yy = np.linspace(-5,5,100)
xx = np.zeros((yy.shape[0], 8))
z = neat_model.predict((xx,yy))
plt.title("Transform function")
plt.xlabel(r"$y$")
plt.ylabel(r"$g(y|x=0)$")
plt.scatter(yy, z)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
yy = load_data(data_path)['y_train']
xx = load_data(data_path)['x_train']
z = neat_model.predict((xx,yy))
plt.hist(z, bins=20, label="y transformed")
plt.hist(load_data(data_path)['y_train'], bins=20, label="y")
plt.legend()
# Out:
# 22/22 [==============================] - 0s 911us/step

# %%
from scipy import stats
num_bins=30
plt.hist(z, bins=num_bins, alpha=0.8, density=True)

yy = np.linspace(-4, 4, 1000)
bin_width = (z.max() - z.min()) / num_bins
plt.plot(yy, stats.norm(z.mean(), z.std()).pdf(yy))

# %% [markdown]
# # Analyse initialisation
# https://www.deeplearning.ai/ai-notes/initialization/index.html#III
# $ Var(a^{l}) = n^{l-1}Var(W^l)Var(a^{l-1}) + n^{l-1}\mathbb{E}[W^l]²Var(a^{l-1})$
# Var(a^l) == Var(a^{l-1}) ==>
# $\frac{1}{n^{l-1}} = Var(W^l) + \mathbb{E}[W^l]²$
# Using Uniform with U(0,b)
# $\frac{1}{n^{l-1}} = \frac{1}{12}b² + {\frac{1}{2}b}²$
# ==>
# $b=\sqrt{\frac{3}{n^{l-1}}}$

# %% [markdown]
# ## Uniform(0,1) initialisation

# %%
# recreate model
tf.keras.backend.clear_session()
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=initializers.RandomUniform(minval=0., maxval=1.))
hp_param['net_y_size_trunk_args']['y_base_units'] = [100,100,20]
train_data, val_data, params = fit_func_prepare(hp_param, data_path)
neat_model = get_neat_model(dim_features=train_data[0].shape[1], **params)
tf.keras.utils.plot_model(neat_model, show_shapes=True, to_file='LS_architekture.pdf')
tf.keras.utils.plot_model(neat_model, show_shapes=True)
# Out:
# /home/daniel/miniconda3/envs/py10/lib/python3.10/site-packages/keras/initializers/initializers.py:120: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %% [markdown]
# ### plot activation distribution

# %%
# Generate some random input data
x = np.random.randn(10000, 1)

# Get the activations for the input data
layer_outputs = []
layers = []
layer_names = []
for l in neat_model.layers:
    if l.name in ['dense_4', 'dense_5', 'dense_6', 'dense_1']:
        print(l.output)
        layer_outputs.append(l.output)
        layer_names.append(l.name)
        layers.append(l)
activation_model = tf.keras.models.Model(inputs=neat_model.inputs[1], outputs=layer_outputs)
activations = activation_model.predict(x)

# Plot the activations

# Determine the number of columns for the subplot
num_columns = len(layers)
# Create the subplot
fig, axs = plt.subplots(1, num_columns, figsize=set_size(textwidth, subplots=(1, num_columns), fraction=1.3), sharey=True, sharex=True)
for i, (ax, layer_name, activation) in enumerate(zip(axs, layer_names, activations)):
    ax.set_title(f"Layer_{i}")
    ax.hist(activation.flatten(), bins=20, density=True)
# Adjust the layout and display the plot
plt.tight_layout()
axs[0].set_ylabel(r"$p(a)$")
fig.savefig("Activation_distribution_wrong_uniform.pdf")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_4/Tanh:0', description="created by layer 'dense_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_5/Tanh:0', description="created by layer 'dense_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/BiasAdd:0', description="created by layer 'dense_1'")
# 313/313 [==============================] - 0s 646us/step

# %% [markdown]
# ### plot weight distribution

# %%
# Get the weights for each layer
layer_weights = [layer.get_weights() for layer in layers]

# Create the subplot
fig, axs = plt.subplots(2, num_columns, figsize=(15, 5))

# Plot the weight distribution for each layer
for i, weights in enumerate(layer_weights):
    axs[0,i].set_title(f"Layer {i+1} Weight Distribution")
    flattened_weights = weights[0].flatten()
    axs[0,i].hist(flattened_weights, bins=20)
    axs[1,i].set_title(f"Layer {i+1} Bias Distribution")
    flattened_weights = weights[1].flatten()
    axs[1,i].hist(flattened_weights, bins=20)

# Adjust the layout and display the plot
plt.tight_layout()

# %% [markdown]
# ## abs Xavier initialisation

# %%
# recreate model
tf.keras.backend.clear_session()
def abs_xavier_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    limit = np.sqrt(6. / (fan_in + fan_out))
    return tf.random.uniform(shape, minval=0, maxval=limit, dtype=dtype)
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=abs_xavier_init)
hp_param['net_y_size_trunk_args']['y_base_units'] = [100,100,20]
train_data, val_data, params = fit_func_prepare(hp_param, data_path)
neat_model = get_neat_model(dim_features=train_data[0].shape[1], **params)
tf.keras.utils.plot_model(neat_model)

# %% [markdown]
# ### plot activation distribution

# %%
# Generate some random input data
x = np.random.randn(10000, 1)

# Get the activations for the input data
layer_outputs = []
layers = []
layer_names = []
for l in neat_model.layers:
    if l.name in ['dense_4', 'dense_5', 'dense_6', 'dense_1']:
        print(l.output)
        layer_outputs.append(l.output)
        layer_names.append(l.name)
        layers.append(l)
activation_model = tf.keras.models.Model(inputs=neat_model.inputs[1], outputs=layer_outputs)
activations = activation_model.predict(x)

# Plot the activations

# Determine the number of columns for the subplot
num_columns = len(layers)
# Create the subplot

fig, axs = plt.subplots(1, num_columns, figsize=set_size(textwidth, subplots=(1, num_columns), fraction=1.2), sharey=True, sharex=True)
for i, (ax, layer_name, activation) in enumerate(zip(axs, layer_names, activations)):
    # ax.set_title(layer_name)
    ax.set_title(f"Layer_{i}")
    ax.hist(activation.flatten(), bins=20, density=True)
# Adjust the layout and display the plot
axs[0].set_ylabel(r"$p(a)$")
plt.tight_layout()
fig.savefig("Activation_distribution_wrong_abs_xavier.pdf")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_4/Tanh:0', description="created by layer 'dense_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_5/Tanh:0', description="created by layer 'dense_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/BiasAdd:0', description="created by layer 'dense_1'")
# 313/313 [==============================] - 0s 568us/step

# %% [markdown]
# ### plot weight distribution

# %%
# Get the weights for each layer
layer_weights = [layer.get_weights() for layer in layers]

# Create the subplot
fig, axs = plt.subplots(2, num_columns, figsize=(15, 5))

# Plot the weight distribution for each layer
for i, weights in enumerate(layer_weights):
    axs[0,i].set_title(f"Layer {i+1} Weight Distribution")
    flattened_weights = weights[0].flatten()
    axs[0,i].hist(flattened_weights, bins=20)
    axs[1,i].set_title(f"Layer {i+1} Bias Distribution")
    flattened_weights = weights[1].flatten()
    axs[1,i].hist(flattened_weights, bins=20)

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## adapted Xavier initialisation according equation
# $ b=\sqrt{\frac{3}{n^{l-1}}} $

# %%
# recreate model
tf.keras.backend.clear_session()
def equation_xavier_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    limit = np.sqrt(3. / (fan_in + fan_out))
    return tf.random.uniform(shape, minval=0., maxval=limit, dtype=dtype)
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=equation_xavier_init)
hp_param['net_y_size_trunk_args']['y_base_units'] = [100,100,20]
train_data, val_data, params = fit_func_prepare(hp_param, data_path)
neat_model = get_neat_model(dim_features=train_data[0].shape[1], **params)
tf.keras.utils.plot_model(neat_model)

# %% [markdown]
# ### plot activation distribution

# %%
# Generate some random input data
x = np.random.randn(10000, 1)*0.5

# Get the activations for the input data
layer_outputs = []
layers = []
layer_names = []
for l in neat_model.layers:
    if l.name in ['dense_4', 'dense_5', 'dense_6', 'dense_1']:
        print(l.output)
        layer_outputs.append(l.output)
        layer_names.append(l.name)
        layers.append(l)
activation_model = tf.keras.models.Model(inputs=neat_model.inputs[1], outputs=layer_outputs)
activations = activation_model.predict(x)

# Plot the activations

# Determine the number of columns for the subplot
num_columns = len(layers)
# Create the subplot
fig, axs = plt.subplots(1, num_columns, figsize=set_size(textwidth, subplots=(1, num_columns), fraction=1.2), sharey=True, sharex=True)
for i, (ax, layer_name, activation) in enumerate(zip(axs, layer_names, activations)):
    # ax.set_title(layer_name)
    ax.set_title(f"Layer_{i}")
    ax.hist(activation.flatten(), bins=10, density=True)
# Adjust the layout and display the plot
axs[0].set_ylabel(r"$p(a)$")
plt.tight_layout()
fig.savefig("Activation_distribution_math_xavier.pdf")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_4/Tanh:0', description="created by layer 'dense_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_5/Tanh:0', description="created by layer 'dense_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/BiasAdd:0', description="created by layer 'dense_1'")
# 313/313 [==============================] - 0s 594us/step

# %% [markdown]
# ### plot weight distribution

# %%
# Get the weights for each layer
layer_weights = [layer.get_weights() for layer in layers]

# Create the subplot
fig, axs = plt.subplots(2, num_columns, figsize=(15, 5))

# Plot the weight distribution for each layer
for i, weights in enumerate(layer_weights):
    axs[0,i].set_title(f"Layer {i+1} Weight Distribution")
    flattened_weights = weights[0].flatten()
    axs[0,i].hist(flattened_weights, bins=20)
    axs[1,i].set_title(f"Layer {i+1} Bias Distribution")
    flattened_weights = weights[1].flatten()
    axs[1,i].hist(flattened_weights, bins=20)

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## plot weight and activation distribution of adapted xavier v2

# %%
def constraint_xavier_p_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    # limit = np.sqrt(6. / (fan_in+fan_out))
    limit = np.sqrt(9. / (np.max([fan_in, fan_out])**2))
    return tf.random.uniform(shape, minval=0, maxval=limit, dtype=dtype)

# recreate model
tf.keras.backend.clear_session()
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=constraint_xavier_p_init)
hp_param['net_y_size_trunk_args']['y_base_units'] = [100,100,20]
train_data, val_data, params = fit_func_prepare(hp_param, data_path)
neat_model = get_neat_model(dim_features=train_data[0].shape[1], **params)
tf.keras.utils.plot_model(neat_model)

# %%
# Generate some random input data
x = np.random.randn(10000, 1)

# Get the activations for the input data
layer_outputs = []
layers = []
layer_names = []
for l in neat_model.layers:
    if l.name in [f"dense_{i}" for i in range(4,len(hp_param['net_y_size_trunk_args']['y_base_units'])+4)] + ['dense_1']:
        print(l.output)
        layer_outputs.append(l.output)
        layer_names.append(l.name)
        layers.append(l)
activation_model = tf.keras.models.Model(inputs=neat_model.inputs[1], outputs=layer_outputs)
activations = activation_model.predict(x)

# Plot the activations

# Determine the number of columns for the subplot
num_columns = len(layers)
# Create the subplot
fig, axs = plt.subplots(1, num_columns, figsize=set_size(textwidth, subplots=(1, num_columns), fraction=1.2), sharey=True, sharex=True)
for i, (ax, layer_name, activation) in enumerate(zip(axs, layer_names, activations)):
    # ax.set_title(layer_name)
    ax.set_title(f"Layer_{i}")
    ax.hist(activation.flatten(), bins=20, density=True)
    ax.axvline(activation.flatten().mean(), color='red', linestyle='--', label='Mean')
    # ax.hist(a3.flatten(), bins=20, density=True, alpha=0.5)
    # ax.axvline(a3.flatten().mean(), color='orange', linestyle='--', label='Mean')
    ax.legend()
    print(f"{layer_name} activation std {activation.std()}")
# Adjust the layout and display the plot
axs[0].set_ylabel(r"$p(a)$")
plt.tight_layout()
fig.savefig("Activation_distribution_empirical_init.pdf")
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_4/Tanh:0', description="created by layer 'dense_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_5/Tanh:0', description="created by layer 'dense_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/BiasAdd:0', description="created by layer 'dense_1'")
# 313/313 [==============================] - 0s 655us/step
# dense_4 activation std 0.016949409618973732
# dense_5 activation std 0.022603046149015427
# dense_6 activation std 0.03308303281664848
# dense_1 activation std 0.047444526106119156

# %% [markdown]
# ## plot weight and activation distribution of adapted xavier v2 on large model

# %%
def constraint_xavier_p_init(shape, dtype=None):
    fan_in = shape[0]
    fan_out = shape[1]
    # limit = np.sqrt(6. / (fan_in+fan_out))
    limit = np.sqrt(9. / (np.max([fan_in, fan_out])**2))
    return tf.random.uniform(shape, minval=0, maxval=limit, dtype=dtype)

# recreate model
tf.keras.backend.clear_session()
hp_param['net_y_size_trunk_args']['kwargs'] = dict(kernel_initializer=constraint_xavier_p_init)
hp_param['net_y_size_trunk_args']['y_base_units'] = [10,20,50,100,200,500,200,100,50,10]
train_data, val_data, params = fit_func_prepare(hp_param, data_path)
neat_model = get_neat_model(dim_features=train_data[0].shape[1], **params)
tf.keras.utils.plot_model(neat_model)

# %% [markdown]
# ### plot activation distribution

# %%
# Generate some random input data
x = np.random.randn(10000, 1)

# Get the activations for the input data
layer_outputs = []
layers = []
layer_names = []
for l in neat_model.layers:
    if l.name in  [f"dense_{i}" for i in range(4,len(hp_param['net_y_size_trunk_args']['y_base_units'])+4)] + ['dense_1']:
        print(l.output)
        layer_outputs.append(l.output)
        layer_names.append(l.name)
        layers.append(l)
activation_model = tf.keras.models.Model(inputs=neat_model.inputs[1], outputs=layer_outputs)
activations = activation_model.predict(x)

# Plot the activations

# Determine the number of columns for the subplot
num_columns = len(layers)
subplots = (4, int(np.ceil(num_columns/4)))
# Create the subplot
fig, axs = plt.subplots(*subplots, figsize=set_size(textwidth, subplots=subplots, fraction=1.5), sharey=True, sharex=True)
for ax, layer_name, activation in zip(axs.flatten(), layer_names, activations):
    ax.set_title(layer_name)
    ax.hist(activation.flatten(), bins=20, density=True)
    ax.axvline(activation.flatten().mean(), color='red', linestyle='--', label='Mean')
    # ax.hist(a3.flatten(), bins=20, density=True, alpha=0.5)
    # ax.axvline(a3.flatten().mean(), color='orange', linestyle='--', label='Mean')
    ax.legend()
    print(f"{layer_name} activation std {activation.std()}")
# Adjust the layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name=None), name='dense_4/Tanh:0', description="created by layer 'dense_4'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 20), dtype=tf.float32, name=None), name='dense_5/Tanh:0', description="created by layer 'dense_5'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 50), dtype=tf.float32, name=None), name='dense_6/Tanh:0', description="created by layer 'dense_6'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_7/Tanh:0', description="created by layer 'dense_7'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 200), dtype=tf.float32, name=None), name='dense_8/Tanh:0', description="created by layer 'dense_8'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 500), dtype=tf.float32, name=None), name='dense_9/Tanh:0', description="created by layer 'dense_9'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 200), dtype=tf.float32, name=None), name='dense_10/Tanh:0', description="created by layer 'dense_10'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 100), dtype=tf.float32, name=None), name='dense_11/Tanh:0', description="created by layer 'dense_11'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 50), dtype=tf.float32, name=None), name='dense_12/Tanh:0', description="created by layer 'dense_12'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 10), dtype=tf.float32, name=None), name='dense_13/Tanh:0', description="created by layer 'dense_13'")
# KerasTensor(type_spec=TensorSpec(shape=(None, 1), dtype=tf.float32, name=None), name='dense_1/BiasAdd:0', description="created by layer 'dense_1'")
# 313/313 [==============================] - 0s 1ms/step
# dense_4 activation std 0.17761367559432983
# dense_5 activation std 0.12583769857883453
# dense_6 activation std 0.07240357249975204
# dense_7 activation std 0.05310468003153801
# dense_8 activation std 0.039898552000522614
# dense_9 activation std 0.023877736181020737
# dense_10 activation std 0.03573606163263321
# dense_11 activation std 0.05339890718460083
# dense_12 activation std 0.07939419150352478
# dense_13 activation std 0.12255894392728806
# dense_1 activation std 0.16729336977005005

# %%
# # Xavier without harmonic mean b=sqrt(12/fan_in)
# initial_weights = [l.get_weights() for l in layers]
# # Reinitialize the model parameters with new random values
# for layer, weights in zip(layers, initial_weights):
#     if "dense" in layer.name:
#         shape = weights[0].shape
#         fan_in = shape[0]
#         fan_out = shape[1]
#         limit = np.sqrt(6. / (fan_in))
#         limit = tf.convert_to_tensor(limit, dtype=weights[0].dtype)
#         weight_init = tf.random.uniform(weights[0].shape, minval=-limit, maxval=limit, dtype=weights[0].dtype)
#         bias_init = tf.zeros(weights[1].shape)
#         layer.set_weights([weight_init, bias_init])

# %% [markdown]
# ### plot weight distribution

# %%
# Get the weights for each layer
layer_weights = [layer.get_weights() for layer in layers[1:]]

# Create the subplot
fig, axs = plt.subplots(2, num_columns-1, figsize=(15, 5))

# Plot the weight distribution for each layer
for i, weights in enumerate(layer_weights):
    axs[0,i].set_title(f"Layer {i+1} Weight Distribution")
    flattened_weights = weights[0].flatten()
    print("Mean:" ,flattened_weights.mean()*2)
    print("Std:" ,flattened_weights.std())
    axs[0,i].hist(flattened_weights, bins=20)
    axs[1,i].set_title(f"Layer {i+1} Bias Distribution")
    flattened_weights = weights[1].flatten()
    axs[1,i].hist(flattened_weights, bins=20)

# Adjust the layout and display the plot
plt.tight_layout()
plt.show()
# Out:
# Mean: 0.3445473909378052
# Std: 0.07165259
# Mean: 0.1513511687517166
# Std: 0.042657983
# Mean: 0.05823507905006409
# Std: 0.017322563
# Mean: 0.029515312984585762
# Std: 0.008744096
# Mean: 0.015074926428496838
# Std: 0.004325194
# Mean: 0.005992148537188768
# Std: 0.0017343576
# Mean: 0.005995869170874357
# Std: 0.0017318259
# Mean: 0.014973129145801067
# Std: 0.0043671103
# Mean: 0.029869500547647476
# Std: 0.008702985
# Mean: 0.06236041337251663
# Std: 0.01751349
